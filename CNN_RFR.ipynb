# %% [markdown]
# # BIOSTAT 626 Project: Machine Learning Project
#
# ### Predicting Cancer Patient Survival Time by Using Cellular or Subcellular Resolution Spatial Proteomics Data
# #### Group 16: Hyeonji Ha, Seungseok, Lee, Sooyeon Oh

# %% [markdown]
# ## import library

# %%
from typing import NewType
import argparse
import os
import shutil
import time
import numpy as np
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.distributed as dist
import torch.optim as optim
import torch.utils.data
import torch.utils.data.distributed
import torchvision.transforms as transforms
import torchvision.models as models
import matplotlib.pyplot as plt
import math
from tqdm import tqdm
import random
from torch.utils.data.sampler import SubsetRandomSampler as Subset
from copy import deepcopy
import torch.nn.functional as F
import pandas as pd
from sklearn.metrics import mean_absolute_error, r2_score
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer, mean_squared_error

# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Fix Seed deterministic model

# %%
# Fix seed
seed = 1234
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
torch.cuda.manual_seed(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %% [markdown]
# ## Use CUDA

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
momemtum = 0.9

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Data preprocessing
# ### Load images to tensor

# %%
import torch
import pandas as pd
import tifffile as tiff
import numpy as np

# Load the CSV file
labels_df = pd.read_csv('/content/drive/MyDrive/pro626/train/train_data.csv')

# Assuming the TIFF files are named with their patient ID and stored in 'images/' directory
image_path = f'/content/drive/MyDrive/pro626/train/images'
def load_tiff_images_to_tensor(num_patients, num_channels=52, image_size=(150, 150), base_path='', start_num = 0):
    # Initialize a tensor to hold the image data
    images_tensor = torch.zeros((num_patients, num_channels, *image_size))

    for patient_id in range(1, num_patients + 1):  # Assuming IDs start from 1
        # Dynamically generate the image path for each patient_id
        image_path = f'{base_path}/{patient_id + start_num}.tiff'
        image_data = tiff.imread(image_path)  # This loads the multi-channel image
        image_tensor = torch.from_numpy(image_data).float()
        images_tensor[patient_id - 1] = image_tensor

    return images_tensor

# Load images into a tensor
num_patients = 225  # Total number of patients
images_tensor = load_tiff_images_to_tensor(num_patients, base_path = image_path)

# Check if the tensor dimensions match your expectation
print(images_tensor.shape)  # Should print torch.Size([225, 52, 150, 150])
# Out:
# torch.Size([225, 52, 150, 150])

# %%
images_tensor.shape
# Out:
# torch.Size([225, 52, 150, 150])

# %% [markdown]
# ### Gaussian Blur

# %%
import torch
import torch.nn as nn
import math

class GaussianBlur(nn.Module):
    def __init__(self, kernel_size, sigma, in_channels):
        super(GaussianBlur, self).__init__()
        self.kernel_size = kernel_size
        self.sigma = sigma
        self.in_channels = in_channels
        self.padding = kernel_size // 2
        self.kernel = self.create_kernel(kernel_size, sigma, in_channels)

    def create_kernel(self, kernel_size, sigma, in_channels):
        # Create a x, y coordinate grid of shape (kernel_size, kernel_size, 2)
        x_coord = torch.arange(kernel_size)
        x_grid = x_coord.repeat(kernel_size).view(kernel_size, kernel_size)
        y_grid = x_grid.t()
        xy_grid = torch.stack([x_grid, y_grid], dim=-1).float()

        mean = (kernel_size - 1) / 2.
        variance = sigma ** 2.

        # Calculate the 2-dimensional gaussian kernel
        gaussian_kernel = (1. / (2. * math.pi * variance)) * \
                          torch.exp(
                              -torch.sum((xy_grid - mean) ** 2., dim=-1) / \
                              (2 * variance)
                          )
        # Make sure sum of values in gaussian kernel equals 1.
        gaussian_kernel = gaussian_kernel / torch.sum(gaussian_kernel)

        # Reshape to 2d depthwise convolutional weight
        gaussian_kernel = gaussian_kernel.view(1, 1, kernel_size, kernel_size)
        gaussian_kernel = gaussian_kernel.repeat(in_channels, 1, 1, 1)

        gaussian_filter = nn.Conv2d(in_channels=in_channels, out_channels=in_channels, kernel_size=kernel_size,
                                    groups=in_channels, bias=False, padding=self.padding)

        gaussian_filter.weight.data = gaussian_kernel
        gaussian_filter.weight.requires_grad = False

        return gaussian_filter

    def forward(self, x):
        return self.kernel(x)

gaussian_blur = GaussianBlur(kernel_size=5, sigma=1.0, in_channels=52)
# images_tensor_blurred = gaussian_blur(images_tensor_normalized)

# %%
images_tensor_blurred = gaussian_blur(images_tensor)

# %% [markdown]
# ### Labels

# %%
# Convert survival times into a tensor
survival_times = torch.tensor(labels_df['OSmonth'].values).float()

# Each image tensor at index i corresponds to the survival time at index i in survival_times

# %% [markdown]
# ### Normalizaiton

# %%
# Normalize the images tensor to have mean=0 and std=1
# Calculate the mean and std if not already known. Here, assuming the need to calculate:
mean = images_tensor.mean()
std = images_tensor.std()

# Normalize
images_tensor_normalized = (images_tensor - mean) / std

print(f"Mean: {images_tensor.mean()}, Std: {images_tensor.std()}")
# Out:
# Mean: 14.868066787719727, Std: 86.0501480102539

# %% [markdown]
# ### Creating Dataset From Tensor

# %%
from torch.utils.data import TensorDataset, DataLoader, random_split

# Create a dataset from tensors
full_dataset = TensorDataset(images_tensor_normalized, survival_times)

# %% [markdown]
# ### Transformer

# %%
from torchvision import transforms

transform = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    transforms.RandomApply([transforms.GaussianBlur(3)]),
])

# %% [markdown]
# ### Transform dataset to Channel wise dataset

# %%
class SingleChannelDataset(Dataset):
    def __init__(self, full_dataset, channel_index, transform=None, indices=None):
        """
        Args:
            full_dataset (Dataset): The complete dataset containing both images_tensor and labels.
            channel_index (int): The index of the channel to use.
            transform (callable, optional): Optional transform to be applied on a sample.
            indices (list of int, optional): List of indices to use from the full_dataset.
        """
        self.full_dataset = full_dataset
        self.channel_index = channel_index
        self.transform = transform
        self.indices = indices if indices is not None else range(len(full_dataset))

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        actual_idx = self.indices[idx]
        image, label = self.full_dataset[actual_idx]
        # Select the specific channel
        image = image[self.channel_index, :, :].unsqueeze(0)
        if self.transform:
            image = self.transform(image)
        return image, label

# %% [markdown]
# ## Network

# %%
full_dataset_size = len(full_dataset)
test_size = int(0.10 * full_dataset_size)
train_val_size = full_dataset_size - test_size
# Splitting the dataset into training+validation and test

train_val_dataset, test_dataset = random_split(full_dataset, [train_val_size, test_size])



print(f"Size of training+validation set: {len(train_val_dataset)}")
print(f"Size of test set: {len(test_dataset)}")
# Out:
# Size of training+validation set: 203
# Size of test set: 22

# %% [markdown]
# ### Squeeze and excitation block

# %%
class SEBlock(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SEBlock, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

# %% [markdown]
# ### ImageRegressionCNN

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ImageRegressionCNN(nn.Module):
    def __init__(self, reduction = 16):
        super(ImageRegressionCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=5, stride=1, padding=2)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        self.se = SEBlock(16, reduction=16)

        self.conv2 = nn.Conv2d(16, 32, kernel_size=5, stride=1, padding=2)
        self.fc1 = nn.Linear(32 * 37 * 37, 120)
        self.fc2 = nn.Linear(120, 1)



    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.se(x)
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1)  # Flatten
        x = F.relu(self.fc1(x))
        x = self.fc2(x) #for the reduction of computation complexity
        return x

# %% [markdown]
# ### Load model from each prediction

# %%
def load_models_with_states(channel_models_states, device):
    loaded_models = []
    for state_dict in channel_models_states:
        model = ImageRegressionCNN().to(device)
        model.load_state_dict(state_dict)
        model.eval()
        loaded_models.append(model)
    return loaded_models

# %% [markdown]
# ### Collect model predictions

# %%
def collect_channel_predictions(channel_models, val_loader, device):
    """
    Collect predictions from all channel models for the validation set.

    Args:
    - channel_models (list of torch.nn.Module): The trained models for each channel.
    - val_loader (DataLoader): DataLoader for validation dataset.
    - device (torch.device): The device models and data should be moved to for computation.

    Returns:
    - fold_predictions (np.array): Aggregated predictions from all models for the validation set.
    - fold_real_labels (np.array): Actual labels corresponding to the validation set predictions.
    """
    all_predictions = []
    all_labels = []

    for model in channel_models:
        model = model.to(device)
        model.eval()
        predictions = []
        labels = []
        with torch.no_grad():
            for images, real_labels in val_loader:
                images = images.to(device)
                output = model(images)
                predictions.extend(output.cpu().numpy().flatten())
                labels.extend(real_labels.numpy().flatten())

        # Assuming you want to collect predictions from each model
        all_predictions.append(predictions)
        if not all_labels:
            all_labels = labels  # Only set once assuming all models use the same val_loader

    # Convert lists to np.array for compatibility with sklearn metrics
    fold_predictions = np.array(all_predictions).T  # Transpose to align samples with predictions
    fold_real_labels = np.array(all_labels)

    return fold_predictions, fold_real_labels

# %% [markdown]
# ## Train and Validation Step

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from torch.utils.data import Dataset, DataLoader, random_split, SubsetRandomSampler
from copy import deepcopy
import numpy as np


num_channels = 52
num_epochs = 100
kf = KFold(n_splits=5, shuffle=True, random_state=42)

def train_and_evaluate_channel_models(train_idx, val_idx, dataset,num_epochs=100):

    best_models_per_channel = []


    for channel_index in range(num_channels):

        train_dataset = SingleChannelDataset(
            full_dataset=dataset,
            channel_index=channel_index,
            transform=None,  # Optional transform for training dataset
            indices=train_idx  # Indices for training samples
        )

        val_dataset = SingleChannelDataset(
            full_dataset=dataset,
            channel_index=channel_index,
            transform=None,  # Usually no transform for validation dataset
            indices=val_idx  # Indices for validation samples
        )

        # create DataLoader
        train_loader = DataLoader(train_dataset, batch_size=16)
        val_loader = DataLoader(val_dataset, batch_size=16)


        # Model training for the current channel
        model = ImageRegressionCNN().to(device)
        optimizer = optim.Adam(model.parameters(), lr=0.001)
        criterion = nn.SmoothL1Loss()
        #원래는 smooth l1 loss
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)

        best_val_loss = [float('inf')]
        best_model_state = None

        for epoch in range(num_epochs):
            model.train()
            total_train_loss = 0
            for images, labels in train_loader:
                images, labels = images.to(device), labels.to(device)

                optimizer.zero_grad()
                outputs = model(images)
                loss = criterion(outputs, labels.unsqueeze(1))
                loss.backward()
                optimizer.step()
                total_train_loss += loss.item()

            model.eval()
            val_losses = []
            actuals = []
            predictions = []
            total_val_loss = 0
            with torch.no_grad():
                for images, labels in val_loader:
                    images, labels = images.to(device), labels.to(device)
                    outputs = model(images)
                    loss = criterion(outputs, labels.unsqueeze(1))

                    val_losses.append(loss.item())
                    actuals.extend(labels.cpu().numpy())
                    predictions.extend(outputs.squeeze(-1).cpu().numpy())

                    total_val_loss += loss.item()

            avg_val_loss = total_val_loss / len(val_loader)
            print(f"Epoch {epoch+1}, Channel {channel_index}, Val Loss: {avg_val_loss:.4f}")
            avg_val_loss = np.mean(val_losses)
            val_mae = mean_absolute_error(actuals, predictions)
            val_mse = mean_squared_error(actuals, predictions)
            val_r2 = r2_score(actuals, predictions)

            print(f"Channel {channel_index}, Epoch {epoch+1}: Val Loss: {avg_val_loss:.4f}, MAE: {val_mae:.4f}, MSE: {val_mse:.4f}, R²: {val_r2:.4f}")



            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                best_model_state = deepcopy(model.state_dict())
                print(f"Updated best model for channel {channel_index}")

        # After all epochs, save the best model state for this channel
        if best_model_state is not None:
            torch.save(best_model_state, f'best_model_channel_{channel_index}.pth')
            best_models_per_channel.append(best_model_state)

    return best_models_per_channel

# Placeholder for storing model predictions and true labels for ensemble learning
ensemble_features = []
ensemble_labels = []

for fold, (train_idx, val_idx) in enumerate(kf.split(np.arange(len(train_val_dataset)))):
    print(f"Training fold {fold+1}")


    best_models_per_channel = train_and_evaluate_channel_models(train_idx, val_idx, train_val_dataset, num_epochs=num_epochs)


    loaded_models = load_models_with_states(best_models_per_channel, device)


    fold_predictions = []
    for channel_index, model in enumerate(loaded_models):
        val_dataset = torch.utils.data.Subset(SingleChannelDataset(train_val_dataset, channel_index), val_idx)
        val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)


        predictions, real_labels = collect_channel_predictions([model], val_loader, device)


        fold_predictions.append(predictions)


    fold_features = np.hstack(fold_predictions)
    ensemble_features.append(fold_features)
    ensemble_labels.append(real_labels)


ensemble_features = np.concatenate(ensemble_features, axis=0)
ensemble_labels = np.concatenate(ensemble_labels, axis=0)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Epoch 14, Channel 28, Val Loss: 48.7937
# Channel 28, Epoch 14: Val Loss: 48.7937, MAE: 48.0605, MSE: 3352.8242, R²: -0.0116
# Epoch 15, Channel 28, Val Loss: 48.8207
# Channel 28, Epoch 15: Val Loss: 48.8207, MAE: 48.0965, MSE: 3372.3325, R²: -0.0175
# Epoch 16, Channel 28, Val Loss: 48.5197
# Channel 28, Epoch 16: Val Loss: 48.5197, MAE: 48.1110, MSE: 3523.5425, R²: -0.0631
# Epoch 17, Channel 28, Val Loss: 48.6856
# Channel 28, Epoch 17: Val Loss: 48.6856, MAE: 47.9949, MSE: 3369.2375, R²: -0.0166
# Epoch 18, Channel 28, Val Loss: 48.5282
# Channel 28, Epoch 18: Val Loss: 48.5282, MAE: 47.9390, MSE: 3394.6445, R²: -0.0242
# Epoch 19, Channel 28, Val Loss: 48.7837
# Channel 28, Epoch 19: Val Loss: 48.7837, MAE: 47.9174, MSE: 3302.9985, R²: 0.0034
# Epoch 20, Channel 28, Val Loss: 49.0079
# Channel 28, Epoch 20: Val Loss: 49.0079, MAE: 47.9640, MSE: 3284.6394, R²: 0.0090
# Epoch 21, Channel 28, Val Loss: 48.4778
# Channel 28, Epoch 21: Val Loss: 48.4778, MAE: 47.7001, MSE: 3315.6108, R²: -0.0004
# Epoch 22, Channel 28, Val Loss: 48.5393
# Channel 28, Epoch 22: Val Loss: 48.5393, MAE: 47.6479, MSE: 3279.4246, R²: 0.0105
# Epoch 23, Channel 28, Val Loss: 48.3047
# Channel 28, Epoch 23: Val Loss: 48.3047, MAE: 47.5670, MSE: 3348.3364, R²: -0.0103
# Updated best model for channel 28
# Epoch 24, Channel 28, Val Loss: 48.5706
# Channel 28, Epoch 24: Val Loss: 48.5706, MAE: 47.5949, MSE: 3288.4031, R²: 0.0078
# Epoch 25, Channel 28, Val Loss: 48.8262
# Channel 28, Epoch 25: Val Loss: 48.8262, MAE: 47.6461, MSE: 3251.7961, R²: 0.0189
# Epoch 26, Channel 28, Val Loss: 49.2513
# Channel 28, Epoch 26: Val Loss: 49.2513, MAE: 47.8863, MSE: 3275.5278, R²: 0.0117
# Epoch 27, Channel 28, Val Loss: 49.3481
# Channel 28, Epoch 27: Val Loss: 49.3481, MAE: 47.9531, MSE: 3292.5144, R²: 0.0066
# Epoch 28, Channel 28, Val Loss: 48.4133
# Channel 28, Epoch 28: Val Loss: 48.4133, MAE: 47.5558, MSE: 3391.1763, R²: -0.0232
# Epoch 29, Channel 28, Val Loss: 48.9294
# Channel 28, Epoch 29: Val Loss: 48.9294, MAE: 47.6851, MSE: 3326.0437, R²: -0.0035
# Epoch 30, Channel 28, Val Loss: 48.9987
# Channel 28, Epoch 30: Val Loss: 48.9987, MAE: 47.9228, MSE: 3404.4946, R²: -0.0272
# Epoch 31, Channel 28, Val Loss: 49.5034
# Channel 28, Epoch 31: Val Loss: 49.5034, MAE: 48.2022, MSE: 3389.5151, R²: -0.0227
# Epoch 32, Channel 28, Val Loss: 49.7004
# Channel 28, Epoch 32: Val Loss: 49.7004, MAE: 48.4877, MSE: 3462.5625, R²: -0.0447
# Epoch 33, Channel 28, Val Loss: 50.2346
# Channel 28, Epoch 33: Val Loss: 50.2346, MAE: 48.7034, MSE: 3453.1851, R²: -0.0419
# Epoch 34, Channel 28, Val Loss: 50.0581
# Channel 28, Epoch 34: Val Loss: 50.0581, MAE: 48.8160, MSE: 3510.3374, R²: -0.0591
# Epoch 35, Channel 28, Val Loss: 50.8859
# Channel 28, Epoch 35: Val Loss: 50.8859, MAE: 49.2216, MSE: 3541.4243, R²: -0.0685
# Epoch 36, Channel 28, Val Loss: 51.8011
# Channel 28, Epoch 36: Val Loss: 51.8011, MAE: 49.9542, MSE: 3635.7976, R²: -0.0970
# Epoch 37, Channel 28, Val Loss: 50.5631
# Channel 28, Epoch 37: Val Loss: 50.5631, MAE: 49.3029, MSE: 3618.4800, R²: -0.0918
# Epoch 38, Channel 28, Val Loss: 51.8710
# Channel 28, Epoch 38: Val Loss: 51.8710, MAE: 49.9734, MSE: 3708.9341, R²: -0.1191
# Epoch 39, Channel 28, Val Loss: 51.6538
# Channel 28, Epoch 39: Val Loss: 51.6538, MAE: 50.2681, MSE: 3873.2837, R²: -0.1686
# Epoch 40, Channel 28, Val Loss: 52.2620
# Channel 28, Epoch 40: Val Loss: 52.2620, MAE: 50.7249, MSE: 3903.6167, R²: -0.1778
# Epoch 41, Channel 28, Val Loss: 52.3978
# Channel 28, Epoch 41: Val Loss: 52.3978, MAE: 51.6678, MSE: 4258.4561, R²: -0.2849
# Epoch 42, Channel 28, Val Loss: 52.6300
# Channel 28, Epoch 42: Val Loss: 52.6300, MAE: 51.5675, MSE: 4227.6162, R²: -0.2756
# Epoch 43, Channel 28, Val Loss: 53.0027
# Channel 28, Epoch 43: Val Loss: 53.0027, MAE: 51.5274, MSE: 4028.5715, R²: -0.2155
# Epoch 44, Channel 28, Val Loss: 54.5733
# Channel 28, Epoch 44: Val Loss: 54.5733, MAE: 52.5655, MSE: 4090.2612, R²: -0.2341
# Epoch 45, Channel 28, Val Loss: 54.8963
# Channel 28, Epoch 45: Val Loss: 54.8963, MAE: 52.7659, MSE: 4115.4639, R²: -0.2417
# Epoch 46, Channel 28, Val Loss: 54.5449
# Channel 28, Epoch 46: Val Loss: 54.5449, MAE: 52.6609, MSE: 4154.1123, R²: -0.2534
# Epoch 47, Channel 28, Val Loss: 55.0708
# Channel 28, Epoch 47: Val Loss: 55.0708, MAE: 52.9694, MSE: 4197.0317, R²: -0.2663
# Epoch 48, Channel 28, Val Loss: 53.4872
# Channel 28, Epoch 48: Val Loss: 53.4872, MAE: 52.6524, MSE: 4452.6001, R²: -0.3434
# Epoch 49, Channel 28, Val Loss: 54.3090
# Channel 28, Epoch 49: Val Loss: 54.3090, MAE: 53.4154, MSE: 4556.3857, R²: -0.3747
# Epoch 50, Channel 28, Val Loss: 54.9126
# Channel 28, Epoch 50: Val Loss: 54.9126, MAE: 53.2921, MSE: 4345.8779, R²: -0.3112
# Epoch 51, Channel 28, Val Loss: 54.2983
# Channel 28, Epoch 51: Val Loss: 54.2983, MAE: 52.9912, MSE: 4340.7744, R²: -0.3097
# Epoch 52, Channel 28, Val Loss: 55.0604
# Channel 28, Epoch 52: Val Loss: 55.0604, MAE: 53.6798, MSE: 4448.3213, R²: -0.3421
# Epoch 53, Channel 28, Val Loss: 54.8588
# Channel 28, Epoch 53: Val Loss: 54.8588, MAE: 53.7122, MSE: 4496.3047, R²: -0.3566
# Epoch 54, Channel 28, Val Loss: 54.1990
# Channel 28, Epoch 54: Val Loss: 54.1990, MAE: 53.4479, MSE: 4579.7725, R²: -0.3818
# Epoch 55, Channel 28, Val Loss: 54.6341
# Channel 28, Epoch 55: Val Loss: 54.6341, MAE: 53.8017, MSE: 4626.4561, R²: -0.3959
# Epoch 56, Channel 28, Val Loss: 55.5998
# Channel 28, Epoch 56: Val Loss: 55.5998, MAE: 54.6538, MSE: 4739.4854, R²: -0.4300
# Epoch 57, Channel 28, Val Loss: 54.3232
# Channel 28, Epoch 57: Val Loss: 54.3232, MAE: 53.8273, MSE: 4757.9697, R²: -0.4356
# Epoch 58, Channel 28, Val Loss: 55.8801
# Channel 28, Epoch 58: Val Loss: 55.8801, MAE: 55.4005, MSE: 5065.2930, R²: -0.5283
# Epoch 59, Channel 28, Val Loss: 56.7198
# Channel 28, Epoch 59: Val Loss: 56.7198, MAE: 55.6043, MSE: 4848.7251, R²: -0.4630
# Epoch 60, Channel 28, Val Loss: 57.5279
# Channel 28, Epoch 60: Val Loss: 57.5279, MAE: 56.2221, MSE: 4910.1455, R²: -0.4815
# Epoch 61, Channel 28, Val Loss: 60.5205
# Channel 28, Epoch 61: Val Loss: 60.5205, MAE: 58.5303, MSE: 5283.3052, R²: -0.5941
# Epoch 62, Channel 28, Val Loss: 56.8015
# Channel 28, Epoch 62: Val Loss: 56.8015, MAE: 55.7782, MSE: 4986.9097, R²: -0.5046
# Epoch 63, Channel 28, Val Loss: 57.0509
# Channel 28, Epoch 63: Val Loss: 57.0509, MAE: 56.5788, MSE: 5174.4165, R²: -0.5612
# Epoch 64, Channel 28, Val Loss: 55.2639
# Channel 28, Epoch 64: Val Loss: 55.2639, MAE: 54.9267, MSE: 4980.9980, R²: -0.5029
# Epoch 65, Channel 28, Val Loss: 56.8459
# Channel 28, Epoch 65: Val Loss: 56.8459, MAE: 56.9235, MSE: 5454.0225, R²: -0.6456
# Epoch 66, Channel 28, Val Loss: 56.2013
# Channel 28, Epoch 66: Val Loss: 56.2013, MAE: 56.2590, MSE: 5359.6631, R²: -0.6171
# Epoch 67, Channel 28, Val Loss: 56.7128
# Channel 28, Epoch 67: Val Loss: 56.7128, MAE: 56.6893, MSE: 5458.7925, R²: -0.6470
# Epoch 68, Channel 28, Val Loss: 59.5169
# Channel 28, Epoch 68: Val Loss: 59.5169, MAE: 58.6448, MSE: 5551.5015, R²: -0.6750
# Epoch 69, Channel 28, Val Loss: 59.7831
# Channel 28, Epoch 69: Val Loss: 59.7831, MAE: 58.6165, MSE: 5491.1924, R²: -0.6568
# Epoch 70, Channel 28, Val Loss: 60.1214
# Channel 28, Epoch 70: Val Loss: 60.1214, MAE: 59.3499, MSE: 5630.5132, R²: -0.6988
# Epoch 71, Channel 28, Val Loss: 56.9873
# Channel 28, Epoch 71: Val Loss: 56.9873, MAE: 56.4849, MSE: 5293.8584, R²: -0.5973
# Epoch 72, Channel 28, Val Loss: 58.8520
# Channel 28, Epoch 72: Val Loss: 58.8520, MAE: 58.9042, MSE: 5836.9453, R²: -0.7611
# Epoch 73, Channel 28, Val Loss: 57.4922
# Channel 28, Epoch 73: Val Loss: 57.4922, MAE: 57.2014, MSE: 5486.3125, R²: -0.6553
# Epoch 74, Channel 28, Val Loss: 59.9753
# Channel 28, Epoch 74: Val Loss: 59.9753, MAE: 59.4962, MSE: 5783.9546, R²: -0.7451
# Epoch 75, Channel 28, Val Loss: 59.0426
# Channel 28, Epoch 75: Val Loss: 59.0426, MAE: 58.7507, MSE: 5706.9424, R²: -0.7219
# Epoch 76, Channel 28, Val Loss: 59.6130
# Channel 28, Epoch 76: Val Loss: 59.6130, MAE: 59.1735, MSE: 5753.0063, R²: -0.7358
# Epoch 77, Channel 28, Val Loss: 60.3155
# Channel 28, Epoch 77: Val Loss: 60.3155, MAE: 59.7621, MSE: 5872.2305, R²: -0.7718
# Epoch 78, Channel 28, Val Loss: 61.7524
# Channel 28, Epoch 78: Val Loss: 61.7524, MAE: 61.2575, MSE: 6213.9390, R²: -0.8749
# Epoch 79, Channel 28, Val Loss: 60.2858
# Channel 28, Epoch 79: Val Loss: 60.2858, MAE: 60.0231, MSE: 6135.7471, R²: -0.8513
# Epoch 80, Channel 28, Val Loss: 61.4633
# Channel 28, Epoch 80: Val Loss: 61.4633, MAE: 61.0833, MSE: 6274.4438, R²: -0.8931
# Epoch 81, Channel 28, Val Loss: 62.8318
# Channel 28, Epoch 81: Val Loss: 62.8318, MAE: 62.5704, MSE: 6544.4751, R²: -0.9746
# Epoch 82, Channel 28, Val Loss: 60.1627
# Channel 28, Epoch 82: Val Loss: 60.1627, MAE: 59.8640, MSE: 6295.2871, R²: -0.8994
# Epoch 83, Channel 28, Val Loss: 60.1616
# Channel 28, Epoch 83: Val Loss: 60.1616, MAE: 60.6491, MSE: 6489.3662, R²: -0.9580
# Epoch 84, Channel 28, Val Loss: 57.6384
# Channel 28, Epoch 84: Val Loss: 57.6384, MAE: 57.9080, MSE: 5860.5859, R²: -0.7683
# Epoch 85, Channel 28, Val Loss: 60.1645
# Channel 28, Epoch 85: Val Loss: 60.1645, MAE: 60.7317, MSE: 6477.7139, R²: -0.9545
# Epoch 86, Channel 28, Val Loss: 59.2341
# Channel 28, Epoch 86: Val Loss: 59.2341, MAE: 59.9016, MSE: 6505.1616, R²: -0.9627
# Epoch 87, Channel 28, Val Loss: 59.4736
# Channel 28, Epoch 87: Val Loss: 59.4736, MAE: 60.0674, MSE: 6496.7310, R²: -0.9602
# Epoch 88, Channel 28, Val Loss: 58.5745
# Channel 28, Epoch 88: Val Loss: 58.5745, MAE: 59.5427, MSE: 6395.5049, R²: -0.9296
# Epoch 89, Channel 28, Val Loss: 59.4995
# Channel 28, Epoch 89: Val Loss: 59.4995, MAE: 60.1758, MSE: 6547.5732, R²: -0.9755
# Epoch 90, Channel 28, Val Loss: 59.7501
# Channel 28, Epoch 90: Val Loss: 59.7501, MAE: 60.0665, MSE: 6409.3442, R²: -0.9338
# Epoch 91, Channel 28, Val Loss: 62.0679
# Channel 28, Epoch 91: Val Loss: 62.0679, MAE: 62.2371, MSE: 6863.4990, R²: -1.0708
# Epoch 92, Channel 28, Val Loss: 64.2233
# Channel 28, Epoch 92: Val Loss: 64.2233, MAE: 63.9363, MSE: 7241.2915, R²: -1.1848
# Epoch 93, Channel 28, Val Loss: 64.5736
# Channel 28, Epoch 93: Val Loss: 64.5736, MAE: 64.4404, MSE: 7472.6313, R²: -1.2546
# Epoch 94, Channel 28, Val Loss: 64.1144
# Channel 28, Epoch 94: Val Loss: 64.1144, MAE: 63.9480, MSE: 7476.5806, R²: -1.2558
# Epoch 95, Channel 28, Val Loss: 60.0116
# Channel 28, Epoch 95: Val Loss: 60.0116, MAE: 61.1136, MSE: 7160.1445, R²: -1.1604
# Epoch 96, Channel 28, Val Loss: 58.6168
# Channel 28, Epoch 96: Val Loss: 58.6168, MAE: 59.9379, MSE: 6891.0923, R²: -1.0792
# Epoch 97, Channel 28, Val Loss: 60.2754
# Channel 28, Epoch 97: Val Loss: 60.2754, MAE: 61.1869, MSE: 7123.7822, R²: -1.1494
# Epoch 98, Channel 28, Val Loss: 61.1185
# Channel 28, Epoch 98: Val Loss: 61.1185, MAE: 61.8161, MSE: 7134.7080, R²: -1.1527
# Epoch 99, Channel 28, Val Loss: 60.3071
# Channel 28, Epoch 99: Val Loss: 60.3071, MAE: 60.9772, MSE: 6949.1421, R²: -1.0967
# Epoch 100, Channel 28, Val Loss: 62.5165
# Channel 28, Epoch 100: Val Loss: 62.5165, MAE: 63.0197, MSE: 7334.1553, R²: -1.2129
# Epoch 1, Channel 29, Val Loss: 55.3308
# Channel 29, Epoch 1: Val Loss: 55.3308, MAE: 53.3471, MSE: 3845.1367, R²: -0.1602
# Updated best model for channel 29
# Epoch 2, Channel 29, Val Loss: 50.9945
# Channel 29, Epoch 2: Val Loss: 50.9945, MAE: 52.0764, MSE: 4340.5645, R²: -0.3096
# Updated best model for channel 29
# Epoch 3, Channel 29, Val Loss: 49.6611
# Channel 29, Epoch 3: Val Loss: 49.6611, MAE: 48.5707, MSE: 3327.1353, R²: -0.0039
# Updated best model for channel 29
# Epoch 4, Channel 29, Val Loss: 48.7759
# Channel 29, Epoch 4: Val Loss: 48.7759, MAE: 48.7709, MSE: 3687.4465, R²: -0.1126
# Updated best model for channel 29
# Epoch 5, Channel 29, Val Loss: 48.9092
# Channel 29, Epoch 5: Val Loss: 48.9092, MAE: 48.1196, MSE: 3329.0906, R²: -0.0045
# Epoch 6, Channel 29, Val Loss: 48.4106
# Channel 29, Epoch 6: Val Loss: 48.4106, MAE: 48.1258, MSE: 3550.6726, R²: -0.0713
# Updated best model for channel 29
# Epoch 7, Channel 29, Val Loss: 48.5637
# Channel 29, Epoch 7: Val Loss: 48.5637, MAE: 48.0371, MSE: 3412.8071, R²: -0.0297
# Epoch 8, Channel 29, Val Loss: 48.4124
# Channel 29, Epoch 8: Val Loss: 48.4124, MAE: 48.0354, MSE: 3496.4695, R²: -0.0550
# Epoch 9, Channel 29, Val Loss: 48.7182
# Channel 29, Epoch 9: Val Loss: 48.7182, MAE: 48.0382, MSE: 3355.4832, R²: -0.0124
# Epoch 10, Channel 29, Val Loss: 48.5000
# Channel 29, Epoch 10: Val Loss: 48.5000, MAE: 48.3137, MSE: 3597.4148, R²: -0.0854
# Epoch 11, Channel 29, Val Loss: 48.7126
# Channel 29, Epoch 11: Val Loss: 48.7126, MAE: 48.0378, MSE: 3356.8892, R²: -0.0128
# Epoch 12, Channel 29, Val Loss: 48.5374
# Channel 29, Epoch 12: Val Loss: 48.5374, MAE: 48.3770, MSE: 3611.7644, R²: -0.0897
# Epoch 13, Channel 29, Val Loss: 48.7756
# Channel 29, Epoch 13: Val Loss: 48.7756, MAE: 48.0381, MSE: 3342.5449, R²: -0.0085
# Epoch 14, Channel 29, Val Loss: 48.7138
# Channel 29, Epoch 14: Val Loss: 48.7138, MAE: 48.6735, MSE: 3669.2219, R²: -0.1071
# Epoch 15, Channel 29, Val Loss: 49.0396
# Channel 29, Epoch 15: Val Loss: 49.0396, MAE: 48.1979, MSE: 3321.7935, R²: -0.0022
# Epoch 16, Channel 29, Val Loss: 49.1104
# Channel 29, Epoch 16: Val Loss: 49.1104, MAE: 49.3105, MSE: 3799.0632, R²: -0.1463
# Epoch 17, Channel 29, Val Loss: 49.0061
# Channel 29, Epoch 17: Val Loss: 49.0061, MAE: 48.1778, MSE: 3323.1243, R²: -0.0027
# Epoch 18, Channel 29, Val Loss: 48.8984
# Channel 29, Epoch 18: Val Loss: 48.8984, MAE: 48.9699, MSE: 3727.1069, R²: -0.1245
# Epoch 19, Channel 29, Val Loss: 48.9686
# Channel 29, Epoch 19: Val Loss: 48.9686, MAE: 48.1553, MSE: 3324.9819, R²: -0.0032
# Epoch 20, Channel 29, Val Loss: 48.8755
# Channel 29, Epoch 20: Val Loss: 48.8755, MAE: 48.9335, MSE: 3719.8000, R²: -0.1223
# Epoch 21, Channel 29, Val Loss: 48.9809
# Channel 29, Epoch 21: Val Loss: 48.9809, MAE: 48.1627, MSE: 3324.2800, R²: -0.0030
# Epoch 22, Channel 29, Val Loss: 48.9409
# Channel 29, Epoch 22: Val Loss: 48.9409, MAE: 49.0389, MSE: 3741.3110, R²: -0.1288
# Epoch 23, Channel 29, Val Loss: 48.9543
# Channel 29, Epoch 23: Val Loss: 48.9543, MAE: 48.1467, MSE: 3325.7051, R²: -0.0034
# Epoch 24, Channel 29, Val Loss: 48.7925
# Channel 29, Epoch 24: Val Loss: 48.7925, MAE: 48.8013, MSE: 3693.8438, R²: -0.1145
# Epoch 25, Channel 29, Val Loss: 49.0210
# Channel 29, Epoch 25: Val Loss: 49.0210, MAE: 48.1868, MSE: 3322.3125, R²: -0.0024
# Epoch 26, Channel 29, Val Loss: 49.0653
# Channel 29, Epoch 26: Val Loss: 49.0653, MAE: 49.2400, MSE: 3783.9946, R²: -0.1417
# Epoch 27, Channel 29, Val Loss: 48.9826
# Channel 29, Epoch 27: Val Loss: 48.9826, MAE: 48.1637, MSE: 3324.0698, R²: -0.0029
# Epoch 28, Channel 29, Val Loss: 48.8110
# Channel 29, Epoch 28: Val Loss: 48.8110, MAE: 48.8312, MSE: 3699.6934, R²: -0.1163
# Epoch 29, Channel 29, Val Loss: 49.0095
# Channel 29, Epoch 29: Val Loss: 49.0095, MAE: 48.1799, MSE: 3322.7520, R²: -0.0025
# Epoch 30, Channel 29, Val Loss: 49.0091
# Channel 29, Epoch 30: Val Loss: 49.0091, MAE: 49.1497, MSE: 3764.6509, R²: -0.1359
# Epoch 31, Channel 29, Val Loss: 48.9706
# Channel 29, Epoch 31: Val Loss: 48.9706, MAE: 48.1565, MSE: 3324.6040, R²: -0.0031
# Epoch 32, Channel 29, Val Loss: 48.8039
# Channel 29, Epoch 32: Val Loss: 48.8039, MAE: 48.8206, MSE: 3697.7188, R²: -0.1157
# Epoch 33, Channel 29, Val Loss: 49.0108
# Channel 29, Epoch 33: Val Loss: 49.0108, MAE: 48.1806, MSE: 3322.5969, R²: -0.0025
# Epoch 34, Channel 29, Val Loss: 48.4428
# Channel 29, Epoch 34: Val Loss: 48.4428, MAE: 48.2290, MSE: 3580.9858, R²: -0.0805
# Epoch 35, Channel 29, Val Loss: 48.7329
# Channel 29, Epoch 35: Val Loss: 48.7329, MAE: 48.0354, MSE: 3349.9512, R²: -0.0107
# Epoch 36, Channel 29, Val Loss: 48.5027
# Channel 29, Epoch 36: Val Loss: 48.5027, MAE: 48.3236, MSE: 3600.1086, R²: -0.0862
# Epoch 37, Channel 29, Val Loss: 48.7531
# Channel 29, Epoch 37: Val Loss: 48.7531, MAE: 48.0352, MSE: 3345.4185, R²: -0.0094
# Epoch 38, Channel 29, Val Loss: 48.6455
# Channel 29, Epoch 38: Val Loss: 48.6455, MAE: 48.5651, MSE: 3649.6965, R²: -0.1012
# Epoch 39, Channel 29, Val Loss: 48.9581
# Channel 29, Epoch 39: Val Loss: 48.9581, MAE: 48.1490, MSE: 3325.0046, R²: -0.0032
# Epoch 40, Channel 29, Val Loss: 48.8947
# Channel 29, Epoch 40: Val Loss: 48.8947, MAE: 48.9683, MSE: 3727.3894, R²: -0.1246
# Epoch 41, Channel 29, Val Loss: 49.0017
# Channel 29, Epoch 41: Val Loss: 49.0017, MAE: 48.1752, MSE: 3322.7319, R²: -0.0025
# Epoch 42, Channel 29, Val Loss: 48.9210
# Channel 29, Epoch 42: Val Loss: 48.9210, MAE: 49.0108, MSE: 3736.1040, R²: -0.1273
# Epoch 43, Channel 29, Val Loss: 48.9731
# Channel 29, Epoch 43: Val Loss: 48.9731, MAE: 48.1580, MSE: 3324.0859, R²: -0.0029
# Epoch 44, Channel 29, Val Loss: 48.8100
# Channel 29, Epoch 44: Val Loss: 48.8100, MAE: 48.8328, MSE: 3700.4604, R²: -0.1165
# Epoch 45, Channel 29, Val Loss: 49.0018
# Channel 29, Epoch 45: Val Loss: 49.0018, MAE: 48.1753, MSE: 3322.6548, R²: -0.0025
# Epoch 46, Channel 29, Val Loss: 48.8672
# Channel 29, Epoch 46: Val Loss: 48.8672, MAE: 48.9251, MSE: 3718.8171, R²: -0.1220
# Epoch 47, Channel 29, Val Loss: 48.9876
# Channel 29, Epoch 47: Val Loss: 48.9876, MAE: 48.1667, MSE: 3323.3215, R²: -0.0027
# Epoch 48, Channel 29, Val Loss: 48.8246
# Channel 29, Epoch 48: Val Loss: 48.8246, MAE: 48.8571, MSE: 3705.3462, R²: -0.1180
# Epoch 49, Channel 29, Val Loss: 49.0063
# Channel 29, Epoch 49: Val Loss: 49.0063, MAE: 48.1779, MSE: 3322.3608, R²: -0.0024
# Epoch 50, Channel 29, Val Loss: 48.8573
# Channel 29, Epoch 50: Val Loss: 48.8573, MAE: 48.9101, MSE: 3715.9629, R²: -0.1212
# Epoch 51, Channel 29, Val Loss: 49.0004
# Channel 29, Epoch 51: Val Loss: 49.0004, MAE: 48.1744, MSE: 3322.5571, R²: -0.0025
# Epoch 52, Channel 29, Val Loss: 48.8309
# Channel 29, Epoch 52: Val Loss: 48.8309, MAE: 48.8679, MSE: 3707.5767, R²: -0.1186
# Epoch 53, Channel 29, Val Loss: 49.0189
# Channel 29, Epoch 53: Val Loss: 49.0189, MAE: 48.1855, MSE: 3321.8716, R²: -0.0023
# Epoch 54, Channel 29, Val Loss: 48.8525
# Channel 29, Epoch 54: Val Loss: 48.8525, MAE: 48.9019, MSE: 3714.2156, R²: -0.1207
# Epoch 55, Channel 29, Val Loss: 49.0213
# Channel 29, Epoch 55: Val Loss: 49.0213, MAE: 48.1870, MSE: 3321.7231, R²: -0.0022
# Epoch 56, Channel 29, Val Loss: 48.8385
# Channel 29, Epoch 56: Val Loss: 48.8385, MAE: 48.8809, MSE: 3710.2649, R²: -0.1195
# Epoch 57, Channel 29, Val Loss: 49.0105
# Channel 29, Epoch 57: Val Loss: 49.0105, MAE: 48.1805, MSE: 3322.0669, R²: -0.0023
# Epoch 58, Channel 29, Val Loss: 48.8130
# Channel 29, Epoch 58: Val Loss: 48.8130, MAE: 48.8407, MSE: 3702.4270, R²: -0.1171
# Epoch 59, Channel 29, Val Loss: 48.9749
# Channel 29, Epoch 59: Val Loss: 48.9749, MAE: 48.1591, MSE: 3323.7773, R²: -0.0028
# Epoch 60, Channel 29, Val Loss: 48.7645
# Channel 29, Epoch 60: Val Loss: 48.7645, MAE: 48.7615, MSE: 3686.8379, R²: -0.1124
# Epoch 61, Channel 29, Val Loss: 48.9130
# Channel 29, Epoch 61: Val Loss: 48.9130, MAE: 48.1220, MSE: 3327.4824, R²: -0.0040
# Epoch 62, Channel 29, Val Loss: 48.6803
# Channel 29, Epoch 62: Val Loss: 48.6803, MAE: 48.6277, MSE: 3661.7363, R²: -0.1048
# Epoch 63, Channel 29, Val Loss: 48.8539
# Channel 29, Epoch 63: Val Loss: 48.8539, MAE: 48.0865, MSE: 3331.9968, R²: -0.0053
# Epoch 64, Channel 29, Val Loss: 48.5628
# Channel 29, Epoch 64: Val Loss: 48.5628, MAE: 48.4260, MSE: 3624.1941, R²: -0.0935
# Epoch 65, Channel 29, Val Loss: 48.7603
# Channel 29, Epoch 65: Val Loss: 48.7603, MAE: 48.0320, MSE: 3342.9407, R²: -0.0086
# Epoch 66, Channel 29, Val Loss: 48.4402
# Channel 29, Epoch 66: Val Loss: 48.4402, MAE: 48.2028, MSE: 3574.0942, R²: -0.0784
# Epoch 67, Channel 29, Val Loss: 48.5950
# Channel 29, Epoch 67: Val Loss: 48.5950, MAE: 48.0304, MSE: 3393.8794, R²: -0.0240
# Epoch 68, Channel 29, Val Loss: 48.3820
# Channel 29, Epoch 68: Val Loss: 48.3820, MAE: 48.0593, MSE: 3526.6882, R²: -0.0641
# Updated best model for channel 29
# Epoch 69, Channel 29, Val Loss: 48.6744
# Channel 29, Epoch 69: Val Loss: 48.6744, MAE: 48.0306, MSE: 3364.5481, R²: -0.0151
# Epoch 70, Channel 29, Val Loss: 48.4319
# Channel 29, Epoch 70: Val Loss: 48.4319, MAE: 48.1850, MSE: 3570.3965, R²: -0.0773
# Epoch 71, Channel 29, Val Loss: 48.6042
# Channel 29, Epoch 71: Val Loss: 48.6042, MAE: 48.0298, MSE: 3389.6733, R²: -0.0227
# Epoch 72, Channel 29, Val Loss: 48.3866
# Channel 29, Epoch 72: Val Loss: 48.3866, MAE: 48.0833, MSE: 3540.0605, R²: -0.0681
# Epoch 73, Channel 29, Val Loss: 48.6698
# Channel 29, Epoch 73: Val Loss: 48.6698, MAE: 48.0299, MSE: 3365.6086, R²: -0.0155
# Epoch 74, Channel 29, Val Loss: 48.4267
# Channel 29, Epoch 74: Val Loss: 48.4267, MAE: 48.1803, MSE: 3569.8411, R²: -0.0771
# Epoch 75, Channel 29, Val Loss: 48.6052
# Channel 29, Epoch 75: Val Loss: 48.6052, MAE: 48.0284, MSE: 3388.2310, R²: -0.0223
# Epoch 76, Channel 29, Val Loss: 48.3877
# Channel 29, Epoch 76: Val Loss: 48.3877, MAE: 48.0890, MSE: 3541.7969, R²: -0.0686
# Epoch 77, Channel 29, Val Loss: 48.6639
# Channel 29, Epoch 77: Val Loss: 48.6639, MAE: 48.0289, MSE: 3366.9661, R²: -0.0159
# Epoch 78, Channel 29, Val Loss: 48.4215
# Channel 29, Epoch 78: Val Loss: 48.4215, MAE: 48.1685, MSE: 3566.1431, R²: -0.0760
# Epoch 79, Channel 29, Val Loss: 48.6183
# Channel 29, Epoch 79: Val Loss: 48.6183, MAE: 48.0277, MSE: 3382.6489, R²: -0.0206
# Epoch 80, Channel 29, Val Loss: 48.3994
# Channel 29, Epoch 80: Val Loss: 48.3994, MAE: 48.1291, MSE: 3554.3853, R²: -0.0724
# Epoch 81, Channel 29, Val Loss: 48.6580
# Channel 29, Epoch 81: Val Loss: 48.6580, MAE: 48.0271, MSE: 3367.8340, R²: -0.0161
# Epoch 82, Channel 29, Val Loss: 48.4214
# Channel 29, Epoch 82: Val Loss: 48.4214, MAE: 48.1715, MSE: 3567.5879, R²: -0.0764
# Epoch 83, Channel 29, Val Loss: 48.6208
# Channel 29, Epoch 83: Val Loss: 48.6208, MAE: 48.0269, MSE: 3381.1284, R²: -0.0202
# Epoch 84, Channel 29, Val Loss: 48.4001
# Channel 29, Epoch 84: Val Loss: 48.4001, MAE: 48.1297, MSE: 3554.4714, R²: -0.0725
# Epoch 85, Channel 29, Val Loss: 48.6472
# Channel 29, Epoch 85: Val Loss: 48.6472, MAE: 48.0270, MSE: 3371.5247, R²: -0.0173
# Epoch 86, Channel 29, Val Loss: 48.4029
# Channel 29, Epoch 86: Val Loss: 48.4029, MAE: 48.1364, MSE: 3556.5620, R²: -0.0731
# Epoch 87, Channel 29, Val Loss: 48.6591
# Channel 29, Epoch 87: Val Loss: 48.6591, MAE: 48.0268, MSE: 3367.2812, R²: -0.0160
# Epoch 88, Channel 29, Val Loss: 48.4201
# Channel 29, Epoch 88: Val Loss: 48.4201, MAE: 48.1680, MSE: 3566.2800, R²: -0.0760
# Epoch 89, Channel 29, Val Loss: 48.6083
# Channel 29, Epoch 89: Val Loss: 48.6083, MAE: 48.0271, MSE: 3386.1282, R²: -0.0217
# Epoch 90, Channel 29, Val Loss: 48.3855
# Channel 29, Epoch 90: Val Loss: 48.3855, MAE: 48.0915, MSE: 3543.0645, R²: -0.0690
# Epoch 91, Channel 29, Val Loss: 48.6526
# Channel 29, Epoch 91: Val Loss: 48.6526, MAE: 48.0258, MSE: 3368.8579, R²: -0.0164
# Epoch 92, Channel 29, Val Loss: 48.4078
# Channel 29, Epoch 92: Val Loss: 48.4078, MAE: 48.1480, MSE: 3560.3528, R²: -0.0742
# Epoch 93, Channel 29, Val Loss: 48.6330
# Channel 29, Epoch 93: Val Loss: 48.6330, MAE: 48.0254, MSE: 3375.5664, R²: -0.0185
# Epoch 94, Channel 29, Val Loss: 48.3965
# Channel 29, Epoch 94: Val Loss: 48.3965, MAE: 48.1266, MSE: 3554.0132, R²: -0.0723
# Epoch 95, Channel 29, Val Loss: 48.6625
# Channel 29, Epoch 95: Val Loss: 48.6625, MAE: 48.0253, MSE: 3365.2422, R²: -0.0154
# Epoch 96, Channel 29, Val Loss: 48.4207
# Channel 29, Epoch 96: Val Loss: 48.4207, MAE: 48.1730, MSE: 3568.5210, R²: -0.0767
# Epoch 97, Channel 29, Val Loss: 48.5903
# Channel 29, Epoch 97: Val Loss: 48.5903, MAE: 48.0247, MSE: 3391.6633, R²: -0.0233
# Epoch 98, Channel 29, Val Loss: 48.3756
# Channel 29, Epoch 98: Val Loss: 48.3756, MAE: 48.0571, MSE: 3527.7046, R²: -0.0644
# Updated best model for channel 29
# Epoch 99, Channel 29, Val Loss: 48.6585
# Channel 29, Epoch 99: Val Loss: 48.6585, MAE: 48.0255, MSE: 3366.6594, R²: -0.0158
# Epoch 100, Channel 29, Val Loss: 48.4081
# Channel 29, Epoch 100: Val Loss: 48.4081, MAE: 48.1516, MSE: 3561.8491, R²: -0.0747
# Epoch 1, Channel 30, Val Loss: 57.5077
# Channel 30, Epoch 1: Val Loss: 57.5077, MAE: 56.4357, MSE: 4954.2900, R²: -0.4948
# Updated best model for channel 30
# Epoch 2, Channel 30, Val Loss: 45.7363
# Channel 30, Epoch 2: Val Loss: 45.7363, MAE: 46.3357, MSE: 3016.7070, R²: 0.0898
# Updated best model for channel 30
# Epoch 3, Channel 30, Val Loss: 46.0147
# Channel 30, Epoch 3: Val Loss: 46.0147, MAE: 46.7458, MSE: 3170.0002, R²: 0.0436
# Epoch 4, Channel 30, Val Loss: 48.7732
# Channel 30, Epoch 4: Val Loss: 48.7732, MAE: 48.4418, MSE: 3593.8015, R²: -0.0843
# Epoch 5, Channel 30, Val Loss: 47.0295
# Channel 30, Epoch 5: Val Loss: 47.0295, MAE: 47.2317, MSE: 3388.0808, R²: -0.0222
# Epoch 6, Channel 30, Val Loss: 46.3440
# Channel 30, Epoch 6: Val Loss: 46.3440, MAE: 46.5028, MSE: 3117.7153, R²: 0.0593
# Epoch 7, Channel 30, Val Loss: 47.2681
# Channel 30, Epoch 7: Val Loss: 47.2681, MAE: 47.9662, MSE: 3555.7148, R²: -0.0728
# Epoch 8, Channel 30, Val Loss: 46.6556
# Channel 30, Epoch 8: Val Loss: 46.6556, MAE: 47.2051, MSE: 3392.7664, R²: -0.0237
# Epoch 9, Channel 30, Val Loss: 46.5946
# Channel 30, Epoch 9: Val Loss: 46.5946, MAE: 46.8682, MSE: 3288.1152, R²: 0.0079
# Epoch 10, Channel 30, Val Loss: 47.8918
# Channel 30, Epoch 10: Val Loss: 47.8918, MAE: 47.2630, MSE: 3197.1348, R²: 0.0354
# Epoch 11, Channel 30, Val Loss: 46.8803
# Channel 30, Epoch 11: Val Loss: 46.8803, MAE: 46.8563, MSE: 3211.9556, R²: 0.0309
# Epoch 12, Channel 30, Val Loss: 49.8560
# Channel 30, Epoch 12: Val Loss: 49.8560, MAE: 48.4825, MSE: 3261.5173, R²: 0.0159
# Epoch 13, Channel 30, Val Loss: 47.7208
# Channel 30, Epoch 13: Val Loss: 47.7208, MAE: 47.3605, MSE: 3252.2290, R²: 0.0187
# Epoch 14, Channel 30, Val Loss: 46.8515
# Channel 30, Epoch 14: Val Loss: 46.8515, MAE: 49.0309, MSE: 3980.9546, R²: -0.2011
# Epoch 15, Channel 30, Val Loss: 46.6576
# Channel 30, Epoch 15: Val Loss: 46.6576, MAE: 46.6760, MSE: 3071.9214, R²: 0.0731
# Epoch 16, Channel 30, Val Loss: 49.1395
# Channel 30, Epoch 16: Val Loss: 49.1395, MAE: 48.0609, MSE: 3422.8472, R²: -0.0327
# Epoch 17, Channel 30, Val Loss: 47.6655
# Channel 30, Epoch 17: Val Loss: 47.6655, MAE: 47.0753, MSE: 3192.1265, R²: 0.0369
# Epoch 18, Channel 30, Val Loss: 47.2910
# Channel 30, Epoch 18: Val Loss: 47.2910, MAE: 47.4914, MSE: 3294.8843, R²: 0.0059
# Epoch 19, Channel 30, Val Loss: 46.1024
# Channel 30, Epoch 19: Val Loss: 46.1024, MAE: 47.5283, MSE: 3451.9790, R²: -0.0415
# Epoch 20, Channel 30, Val Loss: 46.9098
# Channel 30, Epoch 20: Val Loss: 46.9098, MAE: 47.7901, MSE: 3522.9531, R²: -0.0629
# Epoch 21, Channel 30, Val Loss: 45.8642
# Channel 30, Epoch 21: Val Loss: 45.8642, MAE: 46.6203, MSE: 3230.3398, R²: 0.0253
# Epoch 22, Channel 30, Val Loss: 47.7185
# Channel 30, Epoch 22: Val Loss: 47.7185, MAE: 47.7987, MSE: 3519.1777, R²: -0.0618
# Epoch 23, Channel 30, Val Loss: 47.0921
# Channel 30, Epoch 23: Val Loss: 47.0921, MAE: 47.3331, MSE: 3144.5789, R²: 0.0512
# Epoch 24, Channel 30, Val Loss: 48.2147
# Channel 30, Epoch 24: Val Loss: 48.2147, MAE: 47.7525, MSE: 3450.6609, R²: -0.0411
# Epoch 25, Channel 30, Val Loss: 48.6593
# Channel 30, Epoch 25: Val Loss: 48.6593, MAE: 47.8950, MSE: 3121.6382, R²: 0.0581
# Epoch 26, Channel 30, Val Loss: 57.6568
# Channel 30, Epoch 26: Val Loss: 57.6568, MAE: 54.9544, MSE: 4074.7729, R²: -0.2294
# Epoch 27, Channel 30, Val Loss: 48.0919
# Channel 30, Epoch 27: Val Loss: 48.0919, MAE: 48.5870, MSE: 3539.8508, R²: -0.0680
# Epoch 28, Channel 30, Val Loss: 47.2140
# Channel 30, Epoch 28: Val Loss: 47.2140, MAE: 48.3168, MSE: 3541.0859, R²: -0.0684
# Epoch 29, Channel 30, Val Loss: 47.7830
# Channel 30, Epoch 29: Val Loss: 47.7830, MAE: 48.1900, MSE: 3437.9453, R²: -0.0373
# Epoch 30, Channel 30, Val Loss: 48.0498
# Channel 30, Epoch 30: Val Loss: 48.0498, MAE: 48.2438, MSE: 3361.6680, R²: -0.0143
# Epoch 31, Channel 30, Val Loss: 48.7006
# Channel 30, Epoch 31: Val Loss: 48.7006, MAE: 48.4540, MSE: 3437.7578, R²: -0.0372
# Epoch 32, Channel 30, Val Loss: 49.5753
# Channel 30, Epoch 32: Val Loss: 49.5753, MAE: 48.9200, MSE: 3465.8696, R²: -0.0457
# Epoch 33, Channel 30, Val Loss: 51.9119
# Channel 30, Epoch 33: Val Loss: 51.9119, MAE: 50.5640, MSE: 3540.5886, R²: -0.0683
# Epoch 34, Channel 30, Val Loss: 60.1076
# Channel 30, Epoch 34: Val Loss: 60.1076, MAE: 57.2593, MSE: 4447.3550, R²: -0.3419
# Epoch 35, Channel 30, Val Loss: 50.4622
# Channel 30, Epoch 35: Val Loss: 50.4622, MAE: 50.9280, MSE: 3977.9460, R²: -0.2002
# Epoch 36, Channel 30, Val Loss: 48.4978
# Channel 30, Epoch 36: Val Loss: 48.4978, MAE: 49.5531, MSE: 3599.7024, R²: -0.0861
# Epoch 37, Channel 30, Val Loss: 49.8620
# Channel 30, Epoch 37: Val Loss: 49.8620, MAE: 49.8409, MSE: 3587.3066, R²: -0.0824
# Epoch 38, Channel 30, Val Loss: 51.6465
# Channel 30, Epoch 38: Val Loss: 51.6465, MAE: 50.7205, MSE: 3452.4375, R²: -0.0417
# Epoch 39, Channel 30, Val Loss: 52.5601
# Channel 30, Epoch 39: Val Loss: 52.5601, MAE: 51.1586, MSE: 3733.7070, R²: -0.1265
# Epoch 40, Channel 30, Val Loss: 49.9339
# Channel 30, Epoch 40: Val Loss: 49.9339, MAE: 50.4813, MSE: 3892.0039, R²: -0.1743
# Epoch 41, Channel 30, Val Loss: 48.8471
# Channel 30, Epoch 41: Val Loss: 48.8471, MAE: 50.4188, MSE: 3883.2397, R²: -0.1716
# Epoch 42, Channel 30, Val Loss: 49.9244
# Channel 30, Epoch 42: Val Loss: 49.9244, MAE: 50.4611, MSE: 3709.7922, R²: -0.1193
# Epoch 43, Channel 30, Val Loss: 50.9257
# Channel 30, Epoch 43: Val Loss: 50.9257, MAE: 50.4178, MSE: 3569.4617, R²: -0.0770
# Epoch 44, Channel 30, Val Loss: 52.2308
# Channel 30, Epoch 44: Val Loss: 52.2308, MAE: 51.2595, MSE: 3658.9075, R²: -0.1040
# Epoch 45, Channel 30, Val Loss: 52.1472
# Channel 30, Epoch 45: Val Loss: 52.1472, MAE: 51.3515, MSE: 3618.9290, R²: -0.0919
# Epoch 46, Channel 30, Val Loss: 53.0468
# Channel 30, Epoch 46: Val Loss: 53.0468, MAE: 52.0115, MSE: 3743.6538, R²: -0.1295
# Epoch 47, Channel 30, Val Loss: 55.2773
# Channel 30, Epoch 47: Val Loss: 55.2773, MAE: 53.4398, MSE: 4017.9741, R²: -0.2123
# Epoch 48, Channel 30, Val Loss: 52.8143
# Channel 30, Epoch 48: Val Loss: 52.8143, MAE: 54.2808, MSE: 4742.2510, R²: -0.4308
# Epoch 49, Channel 30, Val Loss: 50.0297
# Channel 30, Epoch 49: Val Loss: 50.0297, MAE: 51.3951, MSE: 3724.7593, R²: -0.1238
# Epoch 50, Channel 30, Val Loss: 55.4192
# Channel 30, Epoch 50: Val Loss: 55.4192, MAE: 53.3519, MSE: 4001.8394, R²: -0.2074
# Epoch 51, Channel 30, Val Loss: 51.3067
# Channel 30, Epoch 51: Val Loss: 51.3067, MAE: 51.8833, MSE: 3965.3008, R²: -0.1964
# Epoch 52, Channel 30, Val Loss: 51.9826
# Channel 30, Epoch 52: Val Loss: 51.9826, MAE: 52.3853, MSE: 4166.2095, R²: -0.2570
# Epoch 53, Channel 30, Val Loss: 50.9117
# Channel 30, Epoch 53: Val Loss: 50.9117, MAE: 52.0647, MSE: 4011.4043, R²: -0.2103
# Epoch 54, Channel 30, Val Loss: 52.5633
# Channel 30, Epoch 54: Val Loss: 52.5633, MAE: 52.0855, MSE: 3843.3738, R²: -0.1596
# Epoch 55, Channel 30, Val Loss: 52.5154
# Channel 30, Epoch 55: Val Loss: 52.5154, MAE: 52.2315, MSE: 3670.9133, R²: -0.1076
# Epoch 56, Channel 30, Val Loss: 55.1223
# Channel 30, Epoch 56: Val Loss: 55.1223, MAE: 53.5862, MSE: 4032.8308, R²: -0.2168
# Epoch 57, Channel 30, Val Loss: 52.1191
# Channel 30, Epoch 57: Val Loss: 52.1191, MAE: 53.1498, MSE: 4472.9180, R²: -0.3496
# Epoch 58, Channel 30, Val Loss: 51.0908
# Channel 30, Epoch 58: Val Loss: 51.0908, MAE: 52.1745, MSE: 3995.8430, R²: -0.2056
# Epoch 59, Channel 30, Val Loss: 54.0335
# Channel 30, Epoch 59: Val Loss: 54.0335, MAE: 52.7115, MSE: 3934.5457, R²: -0.1871
# Epoch 60, Channel 30, Val Loss: 53.8603
# Channel 30, Epoch 60: Val Loss: 53.8603, MAE: 53.0941, MSE: 3934.2710, R²: -0.1870
# Epoch 61, Channel 30, Val Loss: 54.7341
# Channel 30, Epoch 61: Val Loss: 54.7341, MAE: 54.0678, MSE: 3927.7898, R²: -0.1851
# Epoch 62, Channel 30, Val Loss: 53.0607
# Channel 30, Epoch 62: Val Loss: 53.0607, MAE: 53.0306, MSE: 4161.7275, R²: -0.2557
# Epoch 63, Channel 30, Val Loss: 52.5926
# Channel 30, Epoch 63: Val Loss: 52.5926, MAE: 53.7919, MSE: 4613.3252, R²: -0.3919
# Epoch 64, Channel 30, Val Loss: 53.5385
# Channel 30, Epoch 64: Val Loss: 53.5385, MAE: 53.4888, MSE: 3930.2227, R²: -0.1858
# Epoch 65, Channel 30, Val Loss: 53.1694
# Channel 30, Epoch 65: Val Loss: 53.1694, MAE: 52.7724, MSE: 3883.6919, R²: -0.1718
# Epoch 66, Channel 30, Val Loss: 54.4200
# Channel 30, Epoch 66: Val Loss: 54.4200, MAE: 53.5795, MSE: 4075.6016, R²: -0.2297
# Epoch 67, Channel 30, Val Loss: 52.5676
# Channel 30, Epoch 67: Val Loss: 52.5676, MAE: 52.9136, MSE: 4068.8223, R²: -0.2276
# Epoch 68, Channel 30, Val Loss: 52.4567
# Channel 30, Epoch 68: Val Loss: 52.4567, MAE: 52.9196, MSE: 4137.5742, R²: -0.2484
# Epoch 69, Channel 30, Val Loss: 52.8243
# Channel 30, Epoch 69: Val Loss: 52.8243, MAE: 53.0188, MSE: 4259.4331, R²: -0.2852
# Epoch 70, Channel 30, Val Loss: 54.3365
# Channel 30, Epoch 70: Val Loss: 54.3365, MAE: 53.5104, MSE: 4130.7305, R²: -0.2463
# Epoch 71, Channel 30, Val Loss: 60.3426
# Channel 30, Epoch 71: Val Loss: 60.3426, MAE: 58.1768, MSE: 4656.2744, R²: -0.4049
# Epoch 72, Channel 30, Val Loss: 52.3489
# Channel 30, Epoch 72: Val Loss: 52.3489, MAE: 52.8879, MSE: 4155.2490, R²: -0.2537
# Epoch 73, Channel 30, Val Loss: 54.0702
# Channel 30, Epoch 73: Val Loss: 54.0702, MAE: 53.6327, MSE: 4181.6377, R²: -0.2617
# Epoch 74, Channel 30, Val Loss: 53.0320
# Channel 30, Epoch 74: Val Loss: 53.0320, MAE: 53.3426, MSE: 3905.0308, R²: -0.1782
# Epoch 75, Channel 30, Val Loss: 54.0379
# Channel 30, Epoch 75: Val Loss: 54.0379, MAE: 53.3893, MSE: 4163.7993, R²: -0.2563
# Epoch 76, Channel 30, Val Loss: 53.9167
# Channel 30, Epoch 76: Val Loss: 53.9167, MAE: 53.4834, MSE: 4086.9468, R²: -0.2331
# Epoch 77, Channel 30, Val Loss: 54.1057
# Channel 30, Epoch 77: Val Loss: 54.1057, MAE: 53.6642, MSE: 3919.6067, R²: -0.1826
# Epoch 78, Channel 30, Val Loss: 58.3877
# Channel 30, Epoch 78: Val Loss: 58.3877, MAE: 56.6821, MSE: 4404.7983, R²: -0.3290
# Epoch 79, Channel 30, Val Loss: 54.6265
# Channel 30, Epoch 79: Val Loss: 54.6265, MAE: 53.8427, MSE: 4406.5146, R²: -0.3295
# Epoch 80, Channel 30, Val Loss: 53.2684
# Channel 30, Epoch 80: Val Loss: 53.2684, MAE: 53.6177, MSE: 4165.3413, R²: -0.2568
# Epoch 81, Channel 30, Val Loss: 55.5209
# Channel 30, Epoch 81: Val Loss: 55.5209, MAE: 54.7470, MSE: 4268.3242, R²: -0.2878
# Epoch 82, Channel 30, Val Loss: 55.3320
# Channel 30, Epoch 82: Val Loss: 55.3320, MAE: 54.3185, MSE: 4221.5039, R²: -0.2737
# Epoch 83, Channel 30, Val Loss: 54.7772
# Channel 30, Epoch 83: Val Loss: 54.7772, MAE: 54.1730, MSE: 3987.2700, R²: -0.2030
# Epoch 84, Channel 30, Val Loss: 57.6417
# Channel 30, Epoch 84: Val Loss: 57.6417, MAE: 55.8862, MSE: 4337.8086, R²: -0.3088
# Epoch 85, Channel 30, Val Loss: 56.2925
# Channel 30, Epoch 85: Val Loss: 56.2925, MAE: 54.8283, MSE: 4385.3916, R²: -0.3232
# Epoch 86, Channel 30, Val Loss: 53.9963
# Channel 30, Epoch 86: Val Loss: 53.9963, MAE: 54.2705, MSE: 4313.8984, R²: -0.3016
# Epoch 87, Channel 30, Val Loss: 55.3277
# Channel 30, Epoch 87: Val Loss: 55.3277, MAE: 54.8099, MSE: 4390.6548, R²: -0.3247
# Epoch 88, Channel 30, Val Loss: 54.4411
# Channel 30, Epoch 88: Val Loss: 54.4411, MAE: 54.1356, MSE: 4273.5010, R²: -0.2894
# Epoch 89, Channel 30, Val Loss: 54.9601
# Channel 30, Epoch 89: Val Loss: 54.9601, MAE: 54.4014, MSE: 4287.0884, R²: -0.2935
# Epoch 90, Channel 30, Val Loss: 60.4268
# Channel 30, Epoch 90: Val Loss: 60.4268, MAE: 58.1266, MSE: 4606.1235, R²: -0.3898
# Epoch 91, Channel 30, Val Loss: 54.5636
# Channel 30, Epoch 91: Val Loss: 54.5636, MAE: 53.7756, MSE: 4230.6763, R²: -0.2765
# Epoch 92, Channel 30, Val Loss: 56.8678
# Channel 30, Epoch 92: Val Loss: 56.8678, MAE: 55.5463, MSE: 4230.0259, R²: -0.2763
# Epoch 93, Channel 30, Val Loss: 58.3238
# Channel 30, Epoch 93: Val Loss: 58.3238, MAE: 56.7930, MSE: 4380.9233, R²: -0.3218
# Epoch 94, Channel 30, Val Loss: 59.2006
# Channel 30, Epoch 94: Val Loss: 59.2006, MAE: 56.8843, MSE: 4598.3721, R²: -0.3874
# Epoch 95, Channel 30, Val Loss: 56.2417
# Channel 30, Epoch 95: Val Loss: 56.2417, MAE: 55.3175, MSE: 4223.7930, R²: -0.2744
# Epoch 96, Channel 30, Val Loss: 55.6253
# Channel 30, Epoch 96: Val Loss: 55.6253, MAE: 55.2456, MSE: 4501.2822, R²: -0.3581
# Epoch 97, Channel 30, Val Loss: 55.4217
# Channel 30, Epoch 97: Val Loss: 55.4217, MAE: 55.2014, MSE: 4492.4082, R²: -0.3554
# Epoch 98, Channel 30, Val Loss: 58.6244
# Channel 30, Epoch 98: Val Loss: 58.6244, MAE: 56.8209, MSE: 4419.2539, R²: -0.3334
# Epoch 99, Channel 30, Val Loss: 58.7694
# Channel 30, Epoch 99: Val Loss: 58.7694, MAE: 56.6888, MSE: 4540.9175, R²: -0.3701
# Epoch 100, Channel 30, Val Loss: 55.8247
# Channel 30, Epoch 100: Val Loss: 55.8247, MAE: 55.4624, MSE: 4307.0054, R²: -0.2995
# Epoch 1, Channel 31, Val Loss: 51.7746
# Channel 31, Epoch 1: Val Loss: 51.7746, MAE: 50.0648, MSE: 3475.3015, R²: -0.0486
# Updated best model for channel 31
# Epoch 2, Channel 31, Val Loss: 50.2035
# Channel 31, Epoch 2: Val Loss: 50.2035, MAE: 50.8792, MSE: 4123.1460, R²: -0.2440
# Updated best model for channel 31
# Epoch 3, Channel 31, Val Loss: 48.9236
# Channel 31, Epoch 3: Val Loss: 48.9236, MAE: 48.1234, MSE: 3343.2493, R²: -0.0087
# Updated best model for channel 31
# Epoch 4, Channel 31, Val Loss: 48.5995
# Channel 31, Epoch 4: Val Loss: 48.5995, MAE: 48.1013, MSE: 3448.0938, R²: -0.0404
# Updated best model for channel 31
# Epoch 5, Channel 31, Val Loss: 48.5603
# Channel 31, Epoch 5: Val Loss: 48.5603, MAE: 48.0896, MSE: 3458.6235, R²: -0.0435
# Updated best model for channel 31
# Epoch 6, Channel 31, Val Loss: 48.7584
# Channel 31, Epoch 6: Val Loss: 48.7584, MAE: 48.0786, MSE: 3365.3931, R²: -0.0154
# Epoch 7, Channel 31, Val Loss: 48.6401
# Channel 31, Epoch 7: Val Loss: 48.6401, MAE: 48.0712, MSE: 3404.7922, R²: -0.0273
# Epoch 8, Channel 31, Val Loss: 48.4582
# Channel 31, Epoch 8: Val Loss: 48.4582, MAE: 48.0678, MSE: 3501.6184, R²: -0.0565
# Updated best model for channel 31
# Epoch 9, Channel 31, Val Loss: 48.7603
# Channel 31, Epoch 9: Val Loss: 48.7603, MAE: 48.0636, MSE: 3357.7031, R²: -0.0131
# Epoch 10, Channel 31, Val Loss: 48.6894
# Channel 31, Epoch 10: Val Loss: 48.6894, MAE: 48.0623, MSE: 3380.6870, R²: -0.0200
# Epoch 11, Channel 31, Val Loss: 48.5901
# Channel 31, Epoch 11: Val Loss: 48.5901, MAE: 48.0605, MSE: 3422.4922, R²: -0.0326
# Epoch 12, Channel 31, Val Loss: 48.7025
# Channel 31, Epoch 12: Val Loss: 48.7025, MAE: 48.0575, MSE: 3374.3816, R²: -0.0181
# Epoch 13, Channel 31, Val Loss: 48.7234
# Channel 31, Epoch 13: Val Loss: 48.7234, MAE: 48.0565, MSE: 3367.0874, R²: -0.0159
# Epoch 14, Channel 31, Val Loss: 48.7183
# Channel 31, Epoch 14: Val Loss: 48.7183, MAE: 48.0572, MSE: 3369.6211, R²: -0.0167
# Epoch 15, Channel 31, Val Loss: 48.7092
# Channel 31, Epoch 15: Val Loss: 48.7092, MAE: 48.0605, MSE: 3375.5601, R²: -0.0185
# Epoch 16, Channel 31, Val Loss: 48.6874
# Channel 31, Epoch 16: Val Loss: 48.6874, MAE: 48.0647, MSE: 3387.3477, R²: -0.0220
# Epoch 17, Channel 31, Val Loss: 48.6870
# Channel 31, Epoch 17: Val Loss: 48.6870, MAE: 48.0734, MSE: 3394.5957, R²: -0.0242
# Epoch 18, Channel 31, Val Loss: 48.5112
# Channel 31, Epoch 18: Val Loss: 48.5112, MAE: 48.0920, MSE: 3508.1387, R²: -0.0585
# Epoch 19, Channel 31, Val Loss: 48.8965
# Channel 31, Epoch 19: Val Loss: 48.8965, MAE: 48.1030, MSE: 3348.1050, R²: -0.0102
# Epoch 20, Channel 31, Val Loss: 48.8260
# Channel 31, Epoch 20: Val Loss: 48.8260, MAE: 48.0892, MSE: 3358.9243, R²: -0.0135
# Epoch 21, Channel 31, Val Loss: 48.5166
# Channel 31, Epoch 21: Val Loss: 48.5166, MAE: 48.0874, MSE: 3499.9192, R²: -0.0560
# Epoch 22, Channel 31, Val Loss: 48.8193
# Channel 31, Epoch 22: Val Loss: 48.8193, MAE: 48.0959, MSE: 3364.6274, R²: -0.0152
# Epoch 23, Channel 31, Val Loss: 49.2169
# Channel 31, Epoch 23: Val Loss: 49.2169, MAE: 48.2782, MSE: 3324.9290, R²: -0.0032
# Epoch 24, Channel 31, Val Loss: 48.5036
# Channel 31, Epoch 24: Val Loss: 48.5036, MAE: 48.0973, MSE: 3519.2505, R²: -0.0618
# Epoch 25, Channel 31, Val Loss: 48.5038
# Channel 31, Epoch 25: Val Loss: 48.5038, MAE: 48.1003, MSE: 3521.0972, R²: -0.0624
# Epoch 26, Channel 31, Val Loss: 48.8757
# Channel 31, Epoch 26: Val Loss: 48.8757, MAE: 48.0889, MSE: 3348.1172, R²: -0.0102
# Epoch 27, Channel 31, Val Loss: 48.8664
# Channel 31, Epoch 27: Val Loss: 48.8664, MAE: 48.0899, MSE: 3350.3569, R²: -0.0109
# Epoch 28, Channel 31, Val Loss: 48.5038
# Channel 31, Epoch 28: Val Loss: 48.5038, MAE: 48.1315, MSE: 3540.8523, R²: -0.0683
# Epoch 29, Channel 31, Val Loss: 48.7336
# Channel 31, Epoch 29: Val Loss: 48.7336, MAE: 48.0857, MSE: 3391.2559, R²: -0.0232
# Epoch 30, Channel 31, Val Loss: 48.6238
# Channel 31, Epoch 30: Val Loss: 48.6238, MAE: 48.0900, MSE: 3445.6577, R²: -0.0396
# Epoch 31, Channel 31, Val Loss: 48.7818
# Channel 31, Epoch 31: Val Loss: 48.7818, MAE: 48.0974, MSE: 3381.5383, R²: -0.0203
# Epoch 32, Channel 31, Val Loss: 48.7117
# Channel 31, Epoch 32: Val Loss: 48.7117, MAE: 48.1031, MSE: 3413.3098, R²: -0.0299
# Epoch 33, Channel 31, Val Loss: 48.6816
# Channel 31, Epoch 33: Val Loss: 48.6816, MAE: 48.1094, MSE: 3432.8547, R²: -0.0358
# Epoch 34, Channel 31, Val Loss: 48.8934
# Channel 31, Epoch 34: Val Loss: 48.8934, MAE: 48.1465, MSE: 3369.5352, R²: -0.0167
# Epoch 35, Channel 31, Val Loss: 48.8437
# Channel 31, Epoch 35: Val Loss: 48.8437, MAE: 48.1354, MSE: 3384.3647, R²: -0.0211
# Epoch 36, Channel 31, Val Loss: 48.7454
# Channel 31, Epoch 36: Val Loss: 48.7454, MAE: 48.1441, MSE: 3430.1738, R²: -0.0349
# Epoch 37, Channel 31, Val Loss: 48.8404
# Channel 31, Epoch 37: Val Loss: 48.8404, MAE: 48.1886, MSE: 3414.6594, R²: -0.0303
# Epoch 38, Channel 31, Val Loss: 49.0095
# Channel 31, Epoch 38: Val Loss: 49.0095, MAE: 48.1951, MSE: 3364.2766, R²: -0.0151
# Epoch 39, Channel 31, Val Loss: 49.0003
# Channel 31, Epoch 39: Val Loss: 49.0003, MAE: 48.2080, MSE: 3373.5312, R²: -0.0179
# Epoch 40, Channel 31, Val Loss: 48.9135
# Channel 31, Epoch 40: Val Loss: 48.9135, MAE: 48.2047, MSE: 3401.6406, R²: -0.0263
# Epoch 41, Channel 31, Val Loss: 48.8950
# Channel 31, Epoch 41: Val Loss: 48.8950, MAE: 48.2550, MSE: 3436.4426, R²: -0.0368
# Epoch 42, Channel 31, Val Loss: 49.0459
# Channel 31, Epoch 42: Val Loss: 49.0459, MAE: 48.3651, MSE: 3434.3931, R²: -0.0362
# Epoch 43, Channel 31, Val Loss: 49.1291
# Channel 31, Epoch 43: Val Loss: 49.1291, MAE: 48.2674, MSE: 3373.4341, R²: -0.0178
# Epoch 44, Channel 31, Val Loss: 49.0150
# Channel 31, Epoch 44: Val Loss: 49.0150, MAE: 48.3030, MSE: 3435.4543, R²: -0.0365
# Epoch 45, Channel 31, Val Loss: 50.1965
# Channel 31, Epoch 45: Val Loss: 50.1965, MAE: 48.8475, MSE: 3363.7219, R²: -0.0149
# Epoch 46, Channel 31, Val Loss: 50.3920
# Channel 31, Epoch 46: Val Loss: 50.3920, MAE: 48.8857, MSE: 3348.4128, R²: -0.0103
# Epoch 47, Channel 31, Val Loss: 48.9321
# Channel 31, Epoch 47: Val Loss: 48.9321, MAE: 48.5624, MSE: 3631.6472, R²: -0.0957
# Epoch 48, Channel 31, Val Loss: 48.9179
# Channel 31, Epoch 48: Val Loss: 48.9179, MAE: 48.2076, MSE: 3457.3794, R²: -0.0432
# Epoch 49, Channel 31, Val Loss: 49.6646
# Channel 31, Epoch 49: Val Loss: 49.6646, MAE: 48.4867, MSE: 3345.3684, R²: -0.0094
# Epoch 50, Channel 31, Val Loss: 48.8664
# Channel 31, Epoch 50: Val Loss: 48.8664, MAE: 48.3947, MSE: 3601.6196, R²: -0.0867
# Epoch 51, Channel 31, Val Loss: 49.1009
# Channel 31, Epoch 51: Val Loss: 49.1009, MAE: 48.1383, MSE: 3362.8667, R²: -0.0146
# Epoch 52, Channel 31, Val Loss: 49.0396
# Channel 31, Epoch 52: Val Loss: 49.0396, MAE: 48.2005, MSE: 3421.3677, R²: -0.0323
# Epoch 53, Channel 31, Val Loss: 48.9909
# Channel 31, Epoch 53: Val Loss: 48.9909, MAE: 48.3546, MSE: 3569.0671, R²: -0.0769
# Epoch 54, Channel 31, Val Loss: 49.4130
# Channel 31, Epoch 54: Val Loss: 49.4130, MAE: 48.3648, MSE: 3396.0840, R²: -0.0247
# Epoch 55, Channel 31, Val Loss: 49.0164
# Channel 31, Epoch 55: Val Loss: 49.0164, MAE: 48.0548, MSE: 3383.8853, R²: -0.0210
# Epoch 56, Channel 31, Val Loss: 49.2000
# Channel 31, Epoch 56: Val Loss: 49.2000, MAE: 48.2332, MSE: 3425.5247, R²: -0.0335
# Epoch 57, Channel 31, Val Loss: 50.1197
# Channel 31, Epoch 57: Val Loss: 50.1197, MAE: 48.6707, MSE: 3374.9097, R²: -0.0183
# Epoch 58, Channel 31, Val Loss: 49.4873
# Channel 31, Epoch 58: Val Loss: 49.4873, MAE: 48.6160, MSE: 3621.6099, R²: -0.0927
# Epoch 59, Channel 31, Val Loss: 48.3120
# Channel 31, Epoch 59: Val Loss: 48.3120, MAE: 47.5822, MSE: 3530.2976, R²: -0.0652
# Updated best model for channel 31
# Epoch 60, Channel 31, Val Loss: 49.0079
# Channel 31, Epoch 60: Val Loss: 49.0079, MAE: 47.8676, MSE: 3383.9751, R²: -0.0210
# Epoch 61, Channel 31, Val Loss: 50.3165
# Channel 31, Epoch 61: Val Loss: 50.3165, MAE: 49.8518, MSE: 3860.2000, R²: -0.1647
# Epoch 62, Channel 31, Val Loss: 50.3138
# Channel 31, Epoch 62: Val Loss: 50.3138, MAE: 48.9837, MSE: 3506.1218, R²: -0.0579
# Epoch 63, Channel 31, Val Loss: 49.9312
# Channel 31, Epoch 63: Val Loss: 49.9312, MAE: 48.7618, MSE: 3548.6016, R²: -0.0707
# Epoch 64, Channel 31, Val Loss: 49.2658
# Channel 31, Epoch 64: Val Loss: 49.2658, MAE: 48.1440, MSE: 3478.8169, R²: -0.0496
# Epoch 65, Channel 31, Val Loss: 49.7046
# Channel 31, Epoch 65: Val Loss: 49.7046, MAE: 48.8874, MSE: 3712.4043, R²: -0.1201
# Epoch 66, Channel 31, Val Loss: 49.2060
# Channel 31, Epoch 66: Val Loss: 49.2060, MAE: 48.3381, MSE: 3641.9976, R²: -0.0989
# Epoch 67, Channel 31, Val Loss: 48.6737
# Channel 31, Epoch 67: Val Loss: 48.6737, MAE: 47.8421, MSE: 3584.4812, R²: -0.0815
# Epoch 68, Channel 31, Val Loss: 48.8752
# Channel 31, Epoch 68: Val Loss: 48.8752, MAE: 48.0087, MSE: 3606.5698, R²: -0.0882
# Epoch 69, Channel 31, Val Loss: 48.8393
# Channel 31, Epoch 69: Val Loss: 48.8393, MAE: 47.6534, MSE: 3433.8647, R²: -0.0361
# Epoch 70, Channel 31, Val Loss: 49.7234
# Channel 31, Epoch 70: Val Loss: 49.7234, MAE: 48.1830, MSE: 3403.8562, R²: -0.0270
# Epoch 71, Channel 31, Val Loss: 50.1568
# Channel 31, Epoch 71: Val Loss: 50.1568, MAE: 48.2276, MSE: 3363.0286, R²: -0.0147
# Epoch 72, Channel 31, Val Loss: 50.1884
# Channel 31, Epoch 72: Val Loss: 50.1884, MAE: 48.9075, MSE: 3644.3235, R²: -0.0996
# Epoch 73, Channel 31, Val Loss: 49.6250
# Channel 31, Epoch 73: Val Loss: 49.6250, MAE: 48.7150, MSE: 3687.7871, R²: -0.1127
# Epoch 74, Channel 31, Val Loss: 49.1711
# Channel 31, Epoch 74: Val Loss: 49.1711, MAE: 48.0217, MSE: 3490.9976, R²: -0.0533
# Epoch 75, Channel 31, Val Loss: 49.1659
# Channel 31, Epoch 75: Val Loss: 49.1659, MAE: 47.7000, MSE: 3366.0220, R²: -0.0156
# Epoch 76, Channel 31, Val Loss: 49.3884
# Channel 31, Epoch 76: Val Loss: 49.3884, MAE: 47.9916, MSE: 3410.6843, R²: -0.0291
# Epoch 77, Channel 31, Val Loss: 50.2137
# Channel 31, Epoch 77: Val Loss: 50.2137, MAE: 49.5310, MSE: 3787.6589, R²: -0.1428
# Epoch 78, Channel 31, Val Loss: 49.8461
# Channel 31, Epoch 78: Val Loss: 49.8461, MAE: 48.5418, MSE: 3597.8047, R²: -0.0855
# Epoch 79, Channel 31, Val Loss: 49.5937
# Channel 31, Epoch 79: Val Loss: 49.5937, MAE: 48.4642, MSE: 3562.9082, R²: -0.0750
# Epoch 80, Channel 31, Val Loss: 49.8377
# Channel 31, Epoch 80: Val Loss: 49.8377, MAE: 48.7471, MSE: 3646.9009, R²: -0.1003
# Epoch 81, Channel 31, Val Loss: 50.0173
# Channel 31, Epoch 81: Val Loss: 50.0173, MAE: 48.7002, MSE: 3634.4648, R²: -0.0966
# Epoch 82, Channel 31, Val Loss: 49.7659
# Channel 31, Epoch 82: Val Loss: 49.7659, MAE: 48.4999, MSE: 3587.4446, R²: -0.0824
# Epoch 83, Channel 31, Val Loss: 50.0874
# Channel 31, Epoch 83: Val Loss: 50.0874, MAE: 48.7216, MSE: 3663.9028, R²: -0.1055
# Epoch 84, Channel 31, Val Loss: 50.3031
# Channel 31, Epoch 84: Val Loss: 50.3031, MAE: 48.9042, MSE: 3702.1165, R²: -0.1170
# Epoch 85, Channel 31, Val Loss: 50.0639
# Channel 31, Epoch 85: Val Loss: 50.0639, MAE: 48.7631, MSE: 3634.2827, R²: -0.0965
# Epoch 86, Channel 31, Val Loss: 50.3227
# Channel 31, Epoch 86: Val Loss: 50.3227, MAE: 48.8122, MSE: 3616.8989, R²: -0.0913
# Epoch 87, Channel 31, Val Loss: 50.5856
# Channel 31, Epoch 87: Val Loss: 50.5856, MAE: 48.9440, MSE: 3649.7710, R²: -0.1012
# Epoch 88, Channel 31, Val Loss: 50.8307
# Channel 31, Epoch 88: Val Loss: 50.8307, MAE: 48.8835, MSE: 3630.3105, R²: -0.0953
# Epoch 89, Channel 31, Val Loss: 51.2948
# Channel 31, Epoch 89: Val Loss: 51.2948, MAE: 49.2150, MSE: 3701.1843, R²: -0.1167
# Epoch 90, Channel 31, Val Loss: 51.8037
# Channel 31, Epoch 90: Val Loss: 51.8037, MAE: 49.5545, MSE: 3810.4387, R²: -0.1497
# Epoch 91, Channel 31, Val Loss: 52.2302
# Channel 31, Epoch 91: Val Loss: 52.2302, MAE: 50.3422, MSE: 3985.8547, R²: -0.2026
# Epoch 92, Channel 31, Val Loss: 52.4076
# Channel 31, Epoch 92: Val Loss: 52.4076, MAE: 50.6980, MSE: 4101.5132, R²: -0.2375
# Epoch 93, Channel 31, Val Loss: 52.4985
# Channel 31, Epoch 93: Val Loss: 52.4985, MAE: 50.2929, MSE: 4038.1147, R²: -0.2184
# Epoch 94, Channel 31, Val Loss: 52.6201
# Channel 31, Epoch 94: Val Loss: 52.6201, MAE: 50.1570, MSE: 3986.3000, R²: -0.2027
# Epoch 95, Channel 31, Val Loss: 52.2536
# Channel 31, Epoch 95: Val Loss: 52.2536, MAE: 49.9582, MSE: 3904.5476, R²: -0.1781
# Epoch 96, Channel 31, Val Loss: 52.4454
# Channel 31, Epoch 96: Val Loss: 52.4454, MAE: 50.2330, MSE: 3945.9155, R²: -0.1906
# Epoch 97, Channel 31, Val Loss: 53.9264
# Channel 31, Epoch 97: Val Loss: 53.9264, MAE: 50.5017, MSE: 4025.2056, R²: -0.2145
# Epoch 98, Channel 31, Val Loss: 53.8956
# Channel 31, Epoch 98: Val Loss: 53.8956, MAE: 50.7174, MSE: 4045.0718, R²: -0.2205
# Epoch 99, Channel 31, Val Loss: 54.0246
# ...
# Epoch 74, Channel 50, Val Loss: 48.6537
# Channel 50, Epoch 74: Val Loss: 48.6537, MAE: 47.9066, MSE: 3302.9805, R²: 0.0034
# Epoch 75, Channel 50, Val Loss: 48.4137
# Channel 50, Epoch 75: Val Loss: 48.4137, MAE: 47.9202, MSE: 3403.7117, R²: -0.0270
# Epoch 76, Channel 50, Val Loss: 48.2458
# Channel 50, Epoch 76: Val Loss: 48.2458, MAE: 47.8552, MSE: 3450.4614, R²: -0.0411
# Epoch 77, Channel 50, Val Loss: 48.4507
# Channel 50, Epoch 77: Val Loss: 48.4507, MAE: 48.4136, MSE: 3633.3840, R²: -0.0963
# Epoch 78, Channel 50, Val Loss: 48.4464
# Channel 50, Epoch 78: Val Loss: 48.4464, MAE: 48.4287, MSE: 3633.0337, R²: -0.0962
# Epoch 79, Channel 50, Val Loss: 48.3564
# Channel 50, Epoch 79: Val Loss: 48.3564, MAE: 47.7712, MSE: 3343.5767, R²: -0.0088
# Epoch 80, Channel 50, Val Loss: 48.4208
# Channel 50, Epoch 80: Val Loss: 48.4208, MAE: 47.8775, MSE: 3374.9590, R²: -0.0183
# Epoch 81, Channel 50, Val Loss: 48.2360
# Channel 50, Epoch 81: Val Loss: 48.2360, MAE: 47.8192, MSE: 3429.5991, R²: -0.0348
# Epoch 82, Channel 50, Val Loss: 48.6235
# Channel 50, Epoch 82: Val Loss: 48.6235, MAE: 48.6904, MSE: 3684.7324, R²: -0.1118
# Epoch 83, Channel 50, Val Loss: 48.2498
# Channel 50, Epoch 83: Val Loss: 48.2498, MAE: 47.7868, MSE: 3398.4937, R²: -0.0254
# Epoch 84, Channel 50, Val Loss: 48.6266
# Channel 50, Epoch 84: Val Loss: 48.6266, MAE: 47.8885, MSE: 3303.2827, R²: 0.0033
# Epoch 85, Channel 50, Val Loss: 48.4062
# Channel 50, Epoch 85: Val Loss: 48.4062, MAE: 48.3153, MSE: 3597.2234, R²: -0.0854
# Epoch 86, Channel 50, Val Loss: 49.2151
# Channel 50, Epoch 86: Val Loss: 49.2151, MAE: 49.5999, MSE: 3879.8188, R²: -0.1706
# Epoch 87, Channel 50, Val Loss: 48.3881
# Channel 50, Epoch 87: Val Loss: 48.3881, MAE: 47.8606, MSE: 3374.1636, R²: -0.0180
# Epoch 88, Channel 50, Val Loss: 48.4384
# Channel 50, Epoch 88: Val Loss: 48.4384, MAE: 47.8849, MSE: 3369.5110, R²: -0.0166
# Epoch 89, Channel 50, Val Loss: 48.2877
# Channel 50, Epoch 89: Val Loss: 48.2877, MAE: 48.0979, MSE: 3547.5430, R²: -0.0704
# Epoch 90, Channel 50, Val Loss: 48.0912
# Channel 50, Epoch 90: Val Loss: 48.0912, MAE: 47.7937, MSE: 3483.2437, R²: -0.0510
# Epoch 91, Channel 50, Val Loss: 48.6252
# Channel 50, Epoch 91: Val Loss: 48.6252, MAE: 47.8859, MSE: 3280.8530, R²: 0.0101
# Epoch 92, Channel 50, Val Loss: 48.3237
# Channel 50, Epoch 92: Val Loss: 48.3237, MAE: 47.8499, MSE: 3393.3250, R²: -0.0238
# Epoch 93, Channel 50, Val Loss: 48.4255
# Channel 50, Epoch 93: Val Loss: 48.4255, MAE: 48.3083, MSE: 3587.7749, R²: -0.0825
# Epoch 94, Channel 50, Val Loss: 48.2962
# Channel 50, Epoch 94: Val Loss: 48.2962, MAE: 48.0968, MSE: 3542.1665, R²: -0.0687
# Epoch 95, Channel 50, Val Loss: 48.4077
# Channel 50, Epoch 95: Val Loss: 48.4077, MAE: 47.8210, MSE: 3341.8848, R²: -0.0083
# Epoch 96, Channel 50, Val Loss: 48.4734
# Channel 50, Epoch 96: Val Loss: 48.4734, MAE: 47.8417, MSE: 3330.2261, R²: -0.0048
# Epoch 97, Channel 50, Val Loss: 48.9353
# Channel 50, Epoch 97: Val Loss: 48.9353, MAE: 49.1592, MSE: 3770.0845, R²: -0.1375
# Epoch 98, Channel 50, Val Loss: 48.4828
# Channel 50, Epoch 98: Val Loss: 48.4828, MAE: 48.4368, MSE: 3624.1125, R²: -0.0935
# Epoch 99, Channel 50, Val Loss: 48.3010
# Channel 50, Epoch 99: Val Loss: 48.3010, MAE: 47.7764, MSE: 3360.0430, R²: -0.0138
# Epoch 100, Channel 50, Val Loss: 48.4704
# Channel 50, Epoch 100: Val Loss: 48.4704, MAE: 47.8816, MSE: 3351.8547, R²: -0.0113
# Epoch 1, Channel 51, Val Loss: 56.8901
# Channel 51, Epoch 1: Val Loss: 56.8901, MAE: 54.8589, MSE: 3998.4453, R²: -0.2064
# Updated best model for channel 51
# Epoch 2, Channel 51, Val Loss: 51.5331
# Channel 51, Epoch 2: Val Loss: 51.5331, MAE: 52.8682, MSE: 4485.6670, R²: -0.3534
# Updated best model for channel 51
# Epoch 3, Channel 51, Val Loss: 49.9002
# Channel 51, Epoch 3: Val Loss: 49.9002, MAE: 48.7129, MSE: 3332.9250, R²: -0.0056
# Updated best model for channel 51
# Epoch 4, Channel 51, Val Loss: 49.0717
# Channel 51, Epoch 4: Val Loss: 49.0717, MAE: 49.3249, MSE: 3815.3809, R²: -0.1512
# Updated best model for channel 51
# Epoch 5, Channel 51, Val Loss: 49.0819
# Channel 51, Epoch 5: Val Loss: 49.0819, MAE: 48.2185, MSE: 3313.8882, R²: 0.0001
# Epoch 6, Channel 51, Val Loss: 48.8366
# Channel 51, Epoch 6: Val Loss: 48.8366, MAE: 48.9484, MSE: 3734.5493, R²: -0.1268
# Updated best model for channel 51
# Epoch 7, Channel 51, Val Loss: 48.8756
# Channel 51, Epoch 7: Val Loss: 48.8756, MAE: 48.0981, MSE: 3319.7915, R²: -0.0016
# Epoch 8, Channel 51, Val Loss: 48.6288
# Channel 51, Epoch 8: Val Loss: 48.6288, MAE: 48.6177, MSE: 3669.7046, R²: -0.1072
# Updated best model for channel 51
# Epoch 9, Channel 51, Val Loss: 48.7067
# Channel 51, Epoch 9: Val Loss: 48.7067, MAE: 47.9934, MSE: 3334.6472, R²: -0.0061
# Epoch 10, Channel 51, Val Loss: 48.4889
# Channel 51, Epoch 10: Val Loss: 48.4889, MAE: 48.3806, MSE: 3623.8196, R²: -0.0934
# Updated best model for channel 51
# Epoch 11, Channel 51, Val Loss: 48.6250
# Channel 51, Epoch 11: Val Loss: 48.6250, MAE: 47.9784, MSE: 3351.2051, R²: -0.0111
# Epoch 12, Channel 51, Val Loss: 48.3983
# Channel 51, Epoch 12: Val Loss: 48.3983, MAE: 48.2250, MSE: 3588.3945, R²: -0.0827
# Updated best model for channel 51
# Epoch 13, Channel 51, Val Loss: 48.6476
# Channel 51, Epoch 13: Val Loss: 48.6476, MAE: 47.9793, MSE: 3345.2954, R²: -0.0093
# Epoch 14, Channel 51, Val Loss: 48.4127
# Channel 51, Epoch 14: Val Loss: 48.4127, MAE: 48.2519, MSE: 3594.2883, R²: -0.0845
# Epoch 15, Channel 51, Val Loss: 48.6187
# Channel 51, Epoch 15: Val Loss: 48.6187, MAE: 47.9796, MSE: 3353.5605, R²: -0.0118
# Epoch 16, Channel 51, Val Loss: 48.3152
# Channel 51, Epoch 16: Val Loss: 48.3152, MAE: 47.9846, MSE: 3508.3137, R²: -0.0585
# Updated best model for channel 51
# Epoch 17, Channel 51, Val Loss: 48.3468
# Channel 51, Epoch 17: Val Loss: 48.3468, MAE: 47.9812, MSE: 3480.1902, R²: -0.0500
# Epoch 18, Channel 51, Val Loss: 48.7137
# Channel 51, Epoch 18: Val Loss: 48.7137, MAE: 47.9983, MSE: 3334.1602, R²: -0.0060
# Epoch 19, Channel 51, Val Loss: 48.3345
# Channel 51, Epoch 19: Val Loss: 48.3345, MAE: 48.0847, MSE: 3553.1812, R²: -0.0721
# Epoch 20, Channel 51, Val Loss: 48.4046
# Channel 51, Epoch 20: Val Loss: 48.4046, MAE: 47.9815, MSE: 3446.7573, R²: -0.0400
# Epoch 21, Channel 51, Val Loss: 48.3729
# Channel 51, Epoch 21: Val Loss: 48.3729, MAE: 47.9813, MSE: 3464.7117, R²: -0.0454
# Epoch 22, Channel 51, Val Loss: 48.6126
# Channel 51, Epoch 22: Val Loss: 48.6126, MAE: 47.9798, MSE: 3355.7544, R²: -0.0125
# Epoch 23, Channel 51, Val Loss: 48.3229
# Channel 51, Epoch 23: Val Loss: 48.3229, MAE: 47.9815, MSE: 3499.4165, R²: -0.0558
# Epoch 24, Channel 51, Val Loss: 48.4252
# Channel 51, Epoch 24: Val Loss: 48.4252, MAE: 47.9808, MSE: 3435.0854, R²: -0.0364
# Epoch 25, Channel 51, Val Loss: 48.3390
# Channel 51, Epoch 25: Val Loss: 48.3390, MAE: 47.9810, MSE: 3485.6587, R²: -0.0517
# Epoch 26, Channel 51, Val Loss: 48.6090
# Channel 51, Epoch 26: Val Loss: 48.6090, MAE: 47.9797, MSE: 3356.9507, R²: -0.0129
# Epoch 27, Channel 51, Val Loss: 48.3739
# Channel 51, Epoch 27: Val Loss: 48.3739, MAE: 47.9814, MSE: 3464.1851, R²: -0.0452
# Epoch 28, Channel 51, Val Loss: 48.3649
# Channel 51, Epoch 28: Val Loss: 48.3649, MAE: 47.9813, MSE: 3469.5398, R²: -0.0468
# Epoch 29, Channel 51, Val Loss: 48.3816
# Channel 51, Epoch 29: Val Loss: 48.3816, MAE: 47.9809, MSE: 3459.5723, R²: -0.0438
# Epoch 30, Channel 51, Val Loss: 48.6244
# Channel 51, Epoch 30: Val Loss: 48.6244, MAE: 47.9788, MSE: 3352.0500, R²: -0.0114
# Epoch 31, Channel 51, Val Loss: 48.3704
# Channel 51, Epoch 31: Val Loss: 48.3704, MAE: 47.9815, MSE: 3466.4126, R²: -0.0459
# Epoch 32, Channel 51, Val Loss: 48.5368
# Channel 51, Epoch 32: Val Loss: 48.5368, MAE: 47.9807, MSE: 3383.1863, R²: -0.0208
# Epoch 33, Channel 51, Val Loss: 48.3111
# Channel 51, Epoch 33: Val Loss: 48.3111, MAE: 48.0015, MSE: 3517.7800, R²: -0.0614
# Updated best model for channel 51
# Epoch 34, Channel 51, Val Loss: 48.3189
# Channel 51, Epoch 34: Val Loss: 48.3189, MAE: 47.9812, MSE: 3503.9993, R²: -0.0572
# Epoch 35, Channel 51, Val Loss: 48.6504
# Channel 51, Epoch 35: Val Loss: 48.6504, MAE: 47.9795, MSE: 3345.1270, R²: -0.0093
# Epoch 36, Channel 51, Val Loss: 48.4445
# Channel 51, Epoch 36: Val Loss: 48.4445, MAE: 47.9813, MSE: 3425.5300, R²: -0.0335
# Epoch 37, Channel 51, Val Loss: 48.4403
# Channel 51, Epoch 37: Val Loss: 48.4403, MAE: 47.9811, MSE: 3427.4976, R²: -0.0341
# Epoch 38, Channel 51, Val Loss: 48.3839
# Channel 51, Epoch 38: Val Loss: 48.3839, MAE: 47.9816, MSE: 3458.8237, R²: -0.0436
# Epoch 39, Channel 51, Val Loss: 48.3932
# Channel 51, Epoch 39: Val Loss: 48.3932, MAE: 47.9810, MSE: 3453.2507, R²: -0.0419
# Epoch 40, Channel 51, Val Loss: 48.4756
# Channel 51, Epoch 40: Val Loss: 48.4756, MAE: 47.9804, MSE: 3410.1367, R²: -0.0289
# Epoch 41, Channel 51, Val Loss: 48.5670
# Channel 51, Epoch 41: Val Loss: 48.5670, MAE: 47.9803, MSE: 3371.7512, R²: -0.0173
# Epoch 42, Channel 51, Val Loss: 48.5075
# Channel 51, Epoch 42: Val Loss: 48.5075, MAE: 48.4053, MSE: 3629.1023, R²: -0.0950
# Epoch 43, Channel 51, Val Loss: 48.8312
# Channel 51, Epoch 43: Val Loss: 48.8312, MAE: 48.0701, MSE: 3323.2339, R²: -0.0027
# Epoch 44, Channel 51, Val Loss: 48.4236
# Channel 51, Epoch 44: Val Loss: 48.4236, MAE: 48.2680, MSE: 3597.4675, R²: -0.0854
# Epoch 45, Channel 51, Val Loss: 48.5178
# Channel 51, Epoch 45: Val Loss: 48.5178, MAE: 47.9801, MSE: 3391.1577, R²: -0.0232
# Epoch 46, Channel 51, Val Loss: 48.4347
# Channel 51, Epoch 46: Val Loss: 48.4347, MAE: 47.9813, MSE: 3430.9780, R²: -0.0352
# Epoch 47, Channel 51, Val Loss: 48.4730
# Channel 51, Epoch 47: Val Loss: 48.4730, MAE: 47.9811, MSE: 3411.7585, R²: -0.0294
# Epoch 48, Channel 51, Val Loss: 48.3197
# Channel 51, Epoch 48: Val Loss: 48.3197, MAE: 47.9821, MSE: 3505.3320, R²: -0.0576
# Epoch 49, Channel 51, Val Loss: 48.3144
# Channel 51, Epoch 49: Val Loss: 48.3144, MAE: 47.9923, MSE: 3512.5688, R²: -0.0598
# Epoch 50, Channel 51, Val Loss: 48.6459
# Channel 51, Epoch 50: Val Loss: 48.6459, MAE: 47.9782, MSE: 3346.1641, R²: -0.0096
# Epoch 51, Channel 51, Val Loss: 48.4740
# Channel 51, Epoch 51: Val Loss: 48.4740, MAE: 47.9821, MSE: 3411.8203, R²: -0.0294
# Epoch 52, Channel 51, Val Loss: 48.3717
# Channel 51, Epoch 52: Val Loss: 48.3717, MAE: 48.1631, MSE: 3574.3367, R²: -0.0784
# Epoch 53, Channel 51, Val Loss: 48.5781
# Channel 51, Epoch 53: Val Loss: 48.5781, MAE: 47.9805, MSE: 3368.0527, R²: -0.0162
# Epoch 54, Channel 51, Val Loss: 48.5171
# Channel 51, Epoch 54: Val Loss: 48.5171, MAE: 47.9809, MSE: 3391.9844, R²: -0.0234
# Epoch 55, Channel 51, Val Loss: 48.3619
# Channel 51, Epoch 55: Val Loss: 48.3619, MAE: 48.1409, MSE: 3569.6187, R²: -0.0770
# Epoch 56, Channel 51, Val Loss: 48.6939
# Channel 51, Epoch 56: Val Loss: 48.6939, MAE: 47.9823, MSE: 3337.4028, R²: -0.0070
# Epoch 57, Channel 51, Val Loss: 48.3741
# Channel 51, Epoch 57: Val Loss: 48.3741, MAE: 47.9805, MSE: 3464.3313, R²: -0.0453
# Epoch 58, Channel 51, Val Loss: 48.3177
# Channel 51, Epoch 58: Val Loss: 48.3177, MAE: 48.0365, MSE: 3538.1672, R²: -0.0675
# Epoch 59, Channel 51, Val Loss: 48.4348
# Channel 51, Epoch 59: Val Loss: 48.4348, MAE: 47.9812, MSE: 3431.2310, R²: -0.0353
# Epoch 60, Channel 51, Val Loss: 48.6058
# Channel 51, Epoch 60: Val Loss: 48.6058, MAE: 47.9802, MSE: 3358.7324, R²: -0.0134
# Epoch 61, Channel 51, Val Loss: 48.4853
# Channel 51, Epoch 61: Val Loss: 48.4853, MAE: 47.9816, MSE: 3406.5210, R²: -0.0278
# Epoch 62, Channel 51, Val Loss: 48.5008
# Channel 51, Epoch 62: Val Loss: 48.5008, MAE: 48.3936, MSE: 3626.1626, R²: -0.0941
# Epoch 63, Channel 51, Val Loss: 48.7238
# Channel 51, Epoch 63: Val Loss: 48.7238, MAE: 48.0046, MSE: 3332.4993, R²: -0.0055
# Epoch 64, Channel 51, Val Loss: 48.5230
# Channel 51, Epoch 64: Val Loss: 48.5230, MAE: 48.4254, MSE: 3633.4282, R²: -0.0963
# Epoch 65, Channel 51, Val Loss: 48.8389
# Channel 51, Epoch 65: Val Loss: 48.8389, MAE: 48.0752, MSE: 3322.9478, R²: -0.0026
# Epoch 66, Channel 51, Val Loss: 48.8284
# Channel 51, Epoch 66: Val Loss: 48.8284, MAE: 48.9315, MSE: 3730.6445, R²: -0.1256
# Epoch 67, Channel 51, Val Loss: 48.7650
# Channel 51, Epoch 67: Val Loss: 48.7650, MAE: 48.0300, MSE: 3328.4968, R²: -0.0043
# Epoch 68, Channel 51, Val Loss: 48.3140
# Channel 51, Epoch 68: Val Loss: 48.3140, MAE: 48.0215, MSE: 3528.9136, R²: -0.0647
# Epoch 69, Channel 51, Val Loss: 48.3371
# Channel 51, Epoch 69: Val Loss: 48.3371, MAE: 47.9822, MSE: 3489.2336, R²: -0.0528
# Epoch 70, Channel 51, Val Loss: 48.5548
# Channel 51, Epoch 70: Val Loss: 48.5548, MAE: 47.9804, MSE: 3376.9114, R²: -0.0189
# Epoch 71, Channel 51, Val Loss: 48.4365
# Channel 51, Epoch 71: Val Loss: 48.4365, MAE: 47.9821, MSE: 3431.1479, R²: -0.0352
# Epoch 72, Channel 51, Val Loss: 48.3803
# Channel 51, Epoch 72: Val Loss: 48.3803, MAE: 48.1792, MSE: 3577.7820, R²: -0.0795
# Epoch 73, Channel 51, Val Loss: 48.6852
# Channel 51, Epoch 73: Val Loss: 48.6852, MAE: 47.9785, MSE: 3338.7876, R²: -0.0074
# Epoch 74, Channel 51, Val Loss: 48.3285
# Channel 51, Epoch 74: Val Loss: 48.3285, MAE: 48.0625, MSE: 3546.1140, R²: -0.0699
# Epoch 75, Channel 51, Val Loss: 48.5328
# Channel 51, Epoch 75: Val Loss: 48.5328, MAE: 47.9831, MSE: 3387.0488, R²: -0.0219
# Epoch 76, Channel 51, Val Loss: 48.3325
# Channel 51, Epoch 76: Val Loss: 48.3325, MAE: 47.9846, MSE: 3496.5054, R²: -0.0550
# Epoch 77, Channel 51, Val Loss: 48.5885
# Channel 51, Epoch 77: Val Loss: 48.5885, MAE: 47.9831, MSE: 3366.0515, R²: -0.0156
# Epoch 78, Channel 51, Val Loss: 48.3573
# Channel 51, Epoch 78: Val Loss: 48.3573, MAE: 47.9846, MSE: 3478.1543, R²: -0.0494
# Epoch 79, Channel 51, Val Loss: 48.4408
# Channel 51, Epoch 79: Val Loss: 48.4408, MAE: 47.9836, MSE: 3430.3152, R²: -0.0350
# Epoch 80, Channel 51, Val Loss: 48.3744
# Channel 51, Epoch 80: Val Loss: 48.3744, MAE: 47.9834, MSE: 3467.3320, R²: -0.0462
# Epoch 81, Channel 51, Val Loss: 48.4556
# Channel 51, Epoch 81: Val Loss: 48.4556, MAE: 47.9829, MSE: 3422.4937, R²: -0.0326
# Epoch 82, Channel 51, Val Loss: 48.4688
# Channel 51, Epoch 82: Val Loss: 48.4688, MAE: 47.9838, MSE: 3416.5847, R²: -0.0308
# Epoch 83, Channel 51, Val Loss: 48.5511
# Channel 51, Epoch 83: Val Loss: 48.5511, MAE: 47.9830, MSE: 3380.1399, R²: -0.0199
# Epoch 84, Channel 51, Val Loss: 48.4046
# Channel 51, Epoch 84: Val Loss: 48.4046, MAE: 48.2243, MSE: 3587.2754, R²: -0.0823
# Epoch 85, Channel 51, Val Loss: 48.6038
# Channel 51, Epoch 85: Val Loss: 48.6038, MAE: 47.9829, MSE: 3361.1375, R²: -0.0141
# Epoch 86, Channel 51, Val Loss: 48.4646
# Channel 51, Epoch 86: Val Loss: 48.4646, MAE: 47.9847, MSE: 3419.3718, R²: -0.0317
# Epoch 87, Channel 51, Val Loss: 48.3761
# Channel 51, Epoch 87: Val Loss: 48.3761, MAE: 47.9846, MSE: 3467.4507, R²: -0.0462
# Epoch 88, Channel 51, Val Loss: 48.4378
# Channel 51, Epoch 88: Val Loss: 48.4378, MAE: 47.9857, MSE: 3433.8313, R²: -0.0361
# Epoch 89, Channel 51, Val Loss: 48.3611
# Channel 51, Epoch 89: Val Loss: 48.3611, MAE: 47.9854, MSE: 3477.2886, R²: -0.0492
# Epoch 90, Channel 51, Val Loss: 48.6284
# Channel 51, Epoch 90: Val Loss: 48.6284, MAE: 47.9854, MSE: 3354.6047, R²: -0.0121
# Epoch 91, Channel 51, Val Loss: 48.3265
# Channel 51, Epoch 91: Val Loss: 48.3265, MAE: 47.9913, MSE: 3509.0234, R²: -0.0587
# Epoch 92, Channel 51, Val Loss: 48.4742
# Channel 51, Epoch 92: Val Loss: 48.4742, MAE: 47.9863, MSE: 3415.7493, R²: -0.0306
# Epoch 93, Channel 51, Val Loss: 48.3627
# Channel 51, Epoch 93: Val Loss: 48.3627, MAE: 47.9873, MSE: 3477.7024, R²: -0.0493
# Epoch 94, Channel 51, Val Loss: 48.6091
# Channel 51, Epoch 94: Val Loss: 48.6091, MAE: 47.9862, MSE: 3361.2000, R²: -0.0141
# Epoch 95, Channel 51, Val Loss: 48.3345
# Channel 51, Epoch 95: Val Loss: 48.3345, MAE: 47.9880, MSE: 3500.4805, R²: -0.0562
# Epoch 96, Channel 51, Val Loss: 48.4736
# Channel 51, Epoch 96: Val Loss: 48.4736, MAE: 47.9862, MSE: 3416.4875, R²: -0.0308
# Epoch 97, Channel 51, Val Loss: 48.3765
# Channel 51, Epoch 97: Val Loss: 48.3765, MAE: 47.9878, MSE: 3470.1921, R²: -0.0470
# Epoch 98, Channel 51, Val Loss: 48.6054
# Channel 51, Epoch 98: Val Loss: 48.6054, MAE: 47.9861, MSE: 3362.5728, R²: -0.0146
# Epoch 99, Channel 51, Val Loss: 48.3423
# Channel 51, Epoch 99: Val Loss: 48.3423, MAE: 47.9893, MSE: 3494.8657, R²: -0.0545
# Epoch 100, Channel 51, Val Loss: 48.4689
# Channel 51, Epoch 100: Val Loss: 48.4689, MAE: 47.9892, MSE: 3420.9399, R²: -0.0322

# %% [markdown]
# ## Ensemble Step
# ### Using RandomForestRegressor

# %%
param_grid = {
    'n_estimators': [50, 100, 150, 200],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}


mse_scorer = make_scorer(mean_squared_error, greater_is_better=False)


grid_search = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, cv=3, scoring=mse_scorer, n_jobs=-1, verbose=2)


grid_search.fit(ensemble_features, ensemble_labels)


print("Best Parameters:", grid_search.best_params_)


best_rf = grid_search.best_estimator_

print("shape of ensemble_features:", ensemble_features.shape)
print("shape of ensemble_labels:", ensemble_labels.shape)


# Optionally, evaluate the ensemble model
test_datasets = [SingleChannelDataset(test_dataset, i) for i in range(num_channels)]

test_loaders = [DataLoader(dataset, batch_size=64, shuffle=False) for dataset in test_datasets]


test_features = []
test_labels = None

for channel_index, loader in enumerate(test_loaders):

    model = ImageRegressionCNN()

    model.load_state_dict(best_models_per_channel[channel_index])

    model = model.to(device)
    model.eval()

    channel_predictions = []
    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            output = model(images)
            channel_predictions.append(output.cpu().numpy())
            if test_labels is None:
                test_labels = labels.numpy()


    test_features.append(np.concatenate(channel_predictions, axis=0))


test_features = np.hstack(test_features)
print(test_features.shape)
predicted_labels = best_rf.predict(test_features)
print("test_labels", test_labels)
print("predicted_labels", predicted_labels)

print("MSE:", mean_squared_error(test_labels, predicted_labels))
print("MAE:", mean_absolute_error(test_labels, predicted_labels))
print("R^2:", r2_score(test_labels, predicted_labels))
# Out:
# Fitting 3 folds for each of 288 candidates, totalling 864 fits
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# Best Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# shape of ensemble_features: (203, 52)
# shape of ensemble_labels: (203,)
# (22, 52)
# test_labels [ 80.  80.  59. 141.  73.  75.  74.  70.  15. 152. 143.   4.  71.  33.
#   18.  72. 101.  61.  95. 167. 112.  20.]
# predicted_labels [ 86.22635137  98.0262381   89.68422985 105.20247619  84.64120058
#   79.42659127  74.30937121  72.22014105  84.29340404  95.9537381
#   96.01925613  59.24657359  91.69037698  77.89561003  84.78417677
#   74.97045635 103.99421429  90.62415476 102.19531421  77.73297258
#   96.89888492  82.69368651]
# MSE: 1633.0499028935767
# MAE: 30.86885286556877
# R^2: 0.16167869461315365

# %%
print(test_features.shape)
predicted_labels = best_rf.predict(test_features)
print("test_labels", test_labels)
print("predicted_labels", predicted_labels)

print("MSE:", mean_squared_error(test_labels, predicted_labels))
print("MAE:", mean_absolute_error(test_labels, predicted_labels))
print("R^2:", r2_score(test_labels, predicted_labels))
# Out:
# (22, 52)
# test_labels [ 80.  80.  59. 141.  73.  75.  74.  70.  15. 152. 143.   4.  71.  33.
#   18.  72. 101.  61.  95. 167. 112.  20.]
# predicted_labels [ 86.22635137  98.0262381   89.68422985 105.20247619  84.64120058
#   79.42659127  74.30937121  72.22014105  84.29340404  95.9537381
#   96.01925613  59.24657359  91.69037698  77.89561003  84.78417677
#   74.97045635 103.99421429  90.62415476 102.19531421  77.73297258
#   96.89888492  82.69368651]
# MSE: 1633.0499028935767
# MAE: 30.86885286556877
# R^2: 0.16167869461315365

# %% [markdown]
# ## Creating Prediction for Test data

# %%
test_image_path = f'/content/drive/MyDrive/pro626/test/images'

# Load images into a tensor
num_patients = 56  # Total number of patients
test_images_tensor = load_tiff_images_to_tensor(num_patients, base_path = test_image_path, start_num = 225)

# Check if the tensor dimensions match your expectation
print(test_images_tensor.shape)  # Should print torch.Size([56, 52, 150, 150])
# Out:
# torch.Size([56, 52, 150, 150])

# %%
# Normalize test images
test_images_tensor_normalized = (test_images_tensor - mean) / std

# %%
class TestSingleChannelDataset(Dataset):
    def __init__(self, images_tensor, channel_index, transform=None):
        """
        Args:
            images_tensor (Tensor): Tensor containing all test images.
            channel_index (int): The index of the channel to use.
            transform (callable, optional): Optional transform to be applied on a sample.
        """
        self.images_tensor = images_tensor
        self.channel_index = channel_index
        self.transform = transform

    def __len__(self):
        return self.images_tensor.shape[0]

    def __getitem__(self, idx):
        # Select the specific channel from the image
        image = self.images_tensor[idx, self.channel_index, :, :].unsqueeze(0)
        if self.transform:
            image = self.transform(image)
        return image

# %%
test_datasets = [TestSingleChannelDataset(test_images_tensor_normalized, i) for i in range(num_channels)]
test_loaders = [DataLoader(dataset, batch_size=64, shuffle=False) for dataset in test_datasets]

# %%
test_features = []

for channel_index, loader in enumerate(test_loaders):
    model = ImageRegressionCNN().to(device)
    model.load_state_dict(best_models_per_channel[channel_index])
    model.eval()

    channel_predictions = []
    with torch.no_grad():
        for images in loader:
            images = images.to(device)
            output = model(images)
            channel_predictions.append(output.cpu().numpy())

    # Concatenate and store predictions for the current channel
    channel_predictions = np.concatenate(channel_predictions, axis=0)
    test_features.append(channel_predictions)

# Combine channel-wise predictions into a single feature matrix
test_features = np.column_stack(test_features)


print(test_features.shape)


predicted_labels = best_rf.predict(test_features)
print("predicted_labels", predicted_labels)
# Out:
# (56, 52)
# predicted_labels [ 94.82862518  73.45169048  54.21322511  81.29628608  59.03768182
#   62.29864683  74.01135354  69.96665837  88.44758405  64.4742619
#   58.15947583  90.78425     89.70351407  95.53655556  96.78537302
#  103.78065476  98.04689899  68.67212662  79.90713131  78.65246429
#   88.70579076  98.82173016 108.44076984  92.38571789 101.1930855
#  104.91861508  85.51320455  84.13770563  93.5202215   96.31644444
#  105.45895635  83.47540079  97.70691739  77.6061746   76.63761905
#  107.62041636  85.70285287  71.40695635  83.60381746  95.15959163
#   94.80846073  89.18442857  84.14862302  83.57384343  90.80359199
#   96.88602128  87.29737698  77.69753175  80.39365476  54.10645635
#   81.39858766  89.3539881   93.2524246   92.16932612  94.87819517
#   98.48466739]

# %%
predicted_df = pd.DataFrame(predicted_labels)

# %%
predicted_df.rename(columns={0: 'pred'}, inplace=True)

predicted_df['patient_no'] = predicted_df.index + 226

predicted_df = predicted_df[['patient_no', 'pred']]

print(predicted_df)
predicted_df.to_csv('/content/drive/MyDrive/pro626/submission.csv', index=False)
# save as txt
predicted_df.to_csv('/content/drive/MyDrive/pro626/submission.txt', sep='\t', index=False)
# Out:
#     patient_no        pred
# 0          226   94.828625
# 1          227   73.451690
# 2          228   54.213225
# 3          229   81.296286
# 4          230   59.037682
# 5          231   62.298647
# 6          232   74.011354
# 7          233   69.966658
# 8          234   88.447584
# 9          235   64.474262
# 10         236   58.159476
# 11         237   90.784250
# 12         238   89.703514
# 13         239   95.536556
# 14         240   96.785373
# 15         241  103.780655
# 16         242   98.046899
# 17         243   68.672127
# 18         244   79.907131
# 19         245   78.652464
# 20         246   88.705791
# 21         247   98.821730
# 22         248  108.440770
# 23         249   92.385718
# 24         250  101.193085
# 25         251  104.918615
# 26         252   85.513205
# 27         253   84.137706
# 28         254   93.520222
# 29         255   96.316444
# 30         256  105.458956
# 31         257   83.475401
# 32         258   97.706917
# 33         259   77.606175
# 34         260   76.637619
# 35         261  107.620416
# 36         262   85.702853
# 37         263   71.406956
# 38         264   83.603817
# 39         265   95.159592
# 40         266   94.808461
# 41         267   89.184429
# 42         268   84.148623
# 43         269   83.573843
# 44         270   90.803592
# 45         271   96.886021
# 46         272   87.297377
# 47         273   77.697532
# 48         274   80.393655
# 49         275   54.106456
# 50         276   81.398588
# 51         277   89.353988
# 52         278   93.252425
# 53         279   92.169326
# 54         280   94.878195
# 55         281   98.484667
